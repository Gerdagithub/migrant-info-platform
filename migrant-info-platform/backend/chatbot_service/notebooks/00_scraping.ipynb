# %% [markdown]
# ## micenter

# %%
import os
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import json
import sys

# Set the base URL
BASE_URL = 'https://micenter.lt/en'
DOMAIN = 'micenter.lt'

# Initialize sets for visited URLs and a list for URLs to visit
visited = set()
to_visit = [BASE_URL]

# Directories
SAVE_DIR = 'micenter_site'
URL_MAP_FILE = os.path.join(SAVE_DIR, 'url_map.json')
LOG_FILE = os.path.join(SAVE_DIR, 'log.txt')

class TeeLogger:
    def __init__(self, *streams):
        self.streams = streams
    def write(self, msg):
        for s in self.streams:
            s.write(msg)
    def flush(self):
        for s in self.streams:
            s.flush()

# Create the directory if it doesn't exist
os.makedirs(SAVE_DIR, exist_ok=True)
            
log_file = open(LOG_FILE, 'w', encoding='utf-8')
original_stdout = sys.stdout
sys.stdout = TeeLogger(sys.stdout, log_file)

if os.path.exists(URL_MAP_FILE):
    shutil.copy(URL_MAP_FILE, URL_MAP_FILE + '.bak')

if os.path.exists(URL_MAP_FILE):
    with open(URL_MAP_FILE, 'r', encoding='utf-8') as f:
        url_map = json.load(f)
else:
    url_map = {}

def sanitize_filename(url):
    """
    Convert a URL into a safe filename by replacing special characters.
    """
    parsed = urlparse(url)
    query = parsed.query.replace('=', '-').replace('&', '_')
    path = parsed.path.strip('/').replace('/', '_')
    if not path:
        path = 'index'
    
    if path and query:
        filename = f"{parsed.netloc}_{path}_{query}.html"
    else:
        filename = f"{parsed.netloc}_{path}.html"
    return filename

def save_html(content, filename):
    """
    Save HTML content to a file within the SAVE_DIR directory.
    """
    filepath = os.path.join(SAVE_DIR, filename)
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(content)

def crawl():
    while to_visit:
        print(f"Progress: {len(visited)} visited | {len(to_visit)} queued")
        is_visited = False
        url = to_visit.pop(0)
        if url in visited:
            continue
            
        filename = sanitize_filename(url)
        filepath = os.path.join(SAVE_DIR, filename)
        if os.path.exists(filepath):
            print(f"Already downloaded: {url}")
            visited.add(url)
            is_visited = True
            
        try:
            response = requests.get(url, timeout=10)
            if response.status_code != 200:
                print(f"Failed to retrieve {url} (Status code: {response.status_code})")
                continue
                
            html_content = response.text
            soup = BeautifulSoup(html_content, 'html.parser')
            if is_visited == False:
                save_html(html_content, filename)
                print(f"Saved: {url}")

            # If the url was saved before, it's overriden
            url_map[filename] = url
            with open(URL_MAP_FILE, 'w', encoding='utf-8') as f:
                json.dump(url_map, f, indent=2, ensure_ascii=False)

            visited.add(url)
            # Extract and process all anchor tags
            for link in soup.find_all('a', href=True):
                href = link['href']
                # Construct absolute URL
                full_url = urljoin(url, href)
                # Normalize URL by removing fragments
                full_url = full_url.split('#')[0]
                # Check if the URL belongs to the same domain and hasn't been visited
                if DOMAIN in urlparse(full_url).netloc and full_url not in visited and full_url not in to_visit:
                    to_visit.append(full_url)
            # Polite delay to prevent overwhelming the server
            time.sleep(1)
            
        except Exception as e:
            print(f"Error processing {url}: {e}")

if __name__ == "__main__":
    crawl()

sys.stdout = original_stdout
log_file.close()
# Out:
# Progress: 0 visited | 1 queued
# Saved: https://micenter.lt/en
# Progress: 1 visited | 71 queued
# Saved: https://micenter.lt/lt
# Progress: 2 visited | 137 queued
# Saved: https://micenter.lt/ru
# Progress: 3 visited | 204 queued
# Saved: https://micenter.lt/en/learn-lithuanian
# Progress: 4 visited | 207 queued
# Saved: https://micenter.lt/en/about-us
# Progress: 5 visited | 206 queued
# Saved: https://micenter.lt/
# Progress: 6 visited | 205 queued
# Saved: https://micenter.lt/en/main-information
# Progress: 7 visited | 204 queued
# Saved: https://micenter.lt/en/interesting-facts
# Progress: 8 visited | 203 queued
# Saved: https://micenter.lt/en/migration-statistics
# Progress: 9 visited | 202 queued
# Saved: https://micenter.lt/en/travel-to-lithuania
# Progress: 10 visited | 201 queued
# Saved: https://micenter.lt/en/schengen-visa
# Progress: 11 visited | 200 queued
# Saved: https://micenter.lt/en/visa-d
# Progress: 12 visited | 199 queued
# Saved: https://micenter.lt/en/temporary-residence-permit
# Progress: 13 visited | 198 queued
# Saved: https://micenter.lt/en/blue-card
# Progress: 14 visited | 197 queued
# Saved: https://micenter.lt/en/permanent-residence-permit
# Progress: 15 visited | 196 queued
# Saved: https://micenter.lt/en/temporary-protection
# Progress: 16 visited | 195 queued
# Failed to retrieve https://micenter.lt/en/arriving-from-ukraine (Status code: 502)
# Progress: 16 visited | 194 queued
# Saved: https://micenter.lt/en/legalization-of-documents
# Progress: 17 visited | 194 queued
# Saved: https://micenter.lt/en/job-search
# Progress: 18 visited | 193 queued
# Saved: https://micenter.lt/en/working-conditions
# Progress: 19 visited | 192 queued
# Saved: https://micenter.lt/en/work-permit
# Progress: 20 visited | 191 queued
# Saved: https://micenter.lt/en/change-of-employer
# Progress: 21 visited | 190 queued
# Saved: https://micenter.lt/en/starting-a-business
# Progress: 22 visited | 189 queued
# Saved: https://micenter.lt/en/violations-of-workers-rights
# Progress: 23 visited | 188 queued
# Saved: https://micenter.lt/en/declaration-of-residence
# Progress: 24 visited | 187 queued
# Saved: https://micenter.lt/en/rental-accomodation
# Progress: 25 visited | 186 queued
# Saved: https://micenter.lt/en/property-purchase
# Progress: 26 visited | 185 queued
# Saved: https://micenter.lt/en/mortgage
# Progress: 27 visited | 184 queued
# Saved: https://micenter.lt/en/healthcare-system
# Progress: 28 visited | 183 queued
# Saved: https://micenter.lt/en/health-insurance
# Progress: 29 visited | 182 queued
# Saved: https://micenter.lt/en/doctors
# Progress: 30 visited | 181 queued
# Saved: https://micenter.lt/en/clinics-and-hospitals
# Progress: 31 visited | 180 queued
# Saved: https://micenter.lt/en/psychological-assistance
# Progress: 32 visited | 179 queued
# Saved: https://micenter.lt/en/pre-school-education
# Progress: 33 visited | 178 queued
# Saved: https://micenter.lt/en/schools
# Progress: 34 visited | 177 queued
# Saved: https://micenter.lt/en/study-in-lithuania
# Progress: 35 visited | 176 queued
# Saved: https://micenter.lt/en/recognition-of-foreign-qualifications
# Progress: 36 visited | 175 queued
# Saved: https://micenter.lt/en/taxes
# Progress: 37 visited | 174 queued
# Saved: https://micenter.lt/en/opening-bank-account
# Progress: 38 visited | 173 queued
# Saved: https://micenter.lt/en/loans
# Progress: 39 visited | 172 queued
# Saved: https://micenter.lt/en/income-declaration
# Progress: 40 visited | 171 queued
# Saved: https://micenter.lt/en/tax-refund
# Progress: 41 visited | 170 queued
# Saved: https://micenter.lt/en/arrival-allowance
# Progress: 42 visited | 169 queued
# Saved: https://micenter.lt/en/benefits-for-parents
# Progress: 43 visited | 168 queued
# Saved: https://micenter.lt/en/shild-benefits
# Progress: 44 visited | 167 queued
# Saved: https://micenter.lt/en/social-benefits
# Progress: 45 visited | 166 queued
# Saved: https://micenter.lt/en/old-age-pension
# Progress: 46 visited | 165 queued
# Saved: https://micenter.lt/en/humanitarian-aid
# Progress: 47 visited | 164 queued
# Saved: https://micenter.lt/en/children
# Progress: 48 visited | 163 queued
# Saved: https://micenter.lt/en/getting-married
# Progress: 49 visited | 162 queued
# Saved: https://micenter.lt/en/divorce
# Progress: 50 visited | 161 queued
# Saved: https://micenter.lt/en/dual-citizenship
# Progress: 51 visited | 160 queued
# Saved: https://micenter.lt/en/lithuanian-citizenship
# Progress: 52 visited | 159 queued
# Saved: https://micenter.lt/en/driving-licence
# Progress: 53 visited | 158 queued
# Saved: https://micenter.lt/en/driving-exams
# Progress: 54 visited | 157 queued
# Saved: https://micenter.lt/en/vehicle-registration
# Progress: 55 visited | 156 queued
# Saved: https://micenter.lt/en/buying-a-vehicle
# Progress: 56 visited | 155 queued
# Saved: https://micenter.lt/en/public-transport
# Progress: 57 visited | 154 queued
# Saved: https://micenter.lt/en/e-services
# Progress: 58 visited | 153 queued
# Saved: https://micenter.lt/en/shopping
# Progress: 59 visited | 152 queued
# Saved: https://micenter.lt/en/telecommunications
# Progress: 60 visited | 151 queued
# Saved: https://micenter.lt/en/bills
# Progress: 61 visited | 150 queued
# Saved: https://micenter.lt/en/what-to-do-in-a-case-of-emergency
# Progress: 62 visited | 149 queued
# Saved: https://micenter.lt/en/elections
# Progress: 63 visited | 148 queued
# Saved: https://micenter.lt/en/how-to-become-a-local
# Progress: 64 visited | 148 queued
# Saved: https://micenter.lt/en/living-in-lithuania
# Progress: 65 visited | 147 queued
# Saved: https://micenter.lt/en/work-in-lithuania
# Progress: 66 visited | 146 queued
# Saved: https://micenter.lt/en/psychological-counselling
# Progress: 67 visited | 145 queued
# Saved: https://micenter.lt/en/orientation-courses
# Progress: 68 visited | 144 queued
# Saved: https://micenter.lt/en/legal-advice
# Progress: 69 visited | 143 queued
# Saved: https://micenter.lt/en/group-therapies
# Progress: 70 visited | 143 queued
# Failed to retrieve https://micenter.lt/cdn-cgi/l/email-protection (Status code: 404)
# Progress: 70 visited | 142 queued
# Saved: https://micenter.lt/lt/lietuviu-kalbos-mokymasis
# Progress: 71 visited | 146 queued
# Saved: https://micenter.lt/lt/apie-mus
# Progress: 72 visited | 145 queued
# Saved: https://micenter.lt/lt/pagrindine-informacija
# Progress: 73 visited | 144 queued
# Saved: https://micenter.lt/lt/idomus-faktai
# Progress: 74 visited | 143 queued
# Saved: https://micenter.lt/lt/migracijos-statistika
# Progress: 75 visited | 142 queued
# Saved: https://micenter.lt/lt/atvykimas-i-lietuva
# Progress: 76 visited | 141 queued
# Saved: https://micenter.lt/lt/sengeno-viza
# Progress: 77 visited | 140 queued
# Saved: https://micenter.lt/lt/viza-d
# Progress: 78 visited | 139 queued
# Saved: https://micenter.lt/lt/leidimas-laikinai-gyventi
# Progress: 79 visited | 138 queued
# Saved: https://micenter.lt/lt/melynoji-kortele
# Progress: 80 visited | 138 queued
# Saved: https://micenter.lt/lt/leidimas-nuolat-gyventi
# Progress: 81 visited | 138 queued
# Saved: https://micenter.lt/lt/laikinoji-apsauga
# Progress: 82 visited | 137 queued
# Saved: https://micenter.lt/lt/atvykstantiems-is-ukrainos
# Progress: 83 visited | 136 queued
# Saved: https://micenter.lt/lt/dokumentu-legalizavimas
# Progress: 84 visited | 135 queued
# Saved: https://micenter.lt/lt/darbo-paieska
# Progress: 85 visited | 134 queued
# Saved: https://micenter.lt/lt/darbo-salygos
# Progress: 86 visited | 133 queued
# Saved: https://micenter.lt/lt/leidimas-dirbti
# Progress: 87 visited | 132 queued
# Saved: https://micenter.lt/lt/darbdavio-keitimas
# Progress: 88 visited | 131 queued
# Saved: https://micenter.lt/lt/verslo-pradzia
# Progress: 89 visited | 130 queued
# Saved: https://micenter.lt/lt/darbuotoju-teisiu-pazeidimai
# Progress: 90 visited | 129 queued
# Saved: https://micenter.lt/lt/gyvenamosios-vietos-deklaravimas
# Progress: 91 visited | 128 queued
# Saved: https://micenter.lt/lt/busto-nuoma
# Progress: 92 visited | 127 queued
# Saved: https://micenter.lt/lt/busto-pirkimas
# Progress: 93 visited | 126 queued
# Saved: https://micenter.lt/lt/busto-paskola
# Progress: 94 visited | 125 queued
# Saved: https://micenter.lt/lt/sveikatos-prieziuros-sistema
# Progress: 95 visited | 124 queued
# Saved: https://micenter.lt/lt/sveikatos-draudimas
# Progress: 96 visited | 123 queued
# Saved: https://micenter.lt/lt/gydytojai
# Progress: 97 visited | 122 queued
# Saved: https://micenter.lt/lt/ligonines-ir-klinikos
# Progress: 98 visited | 121 queued
# Saved: https://micenter.lt/lt/psichologine-pagalba
# Progress: 99 visited | 120 queued
# Saved: https://micenter.lt/lt/darzeliai-ir-priesmokyklinis-ugdymas
# Progress: 100 visited | 119 queued
# Saved: https://micenter.lt/lt/mokyklos
# Progress: 101 visited | 118 queued
# Saved: https://micenter.lt/lt/studijos
# Progress: 102 visited | 117 queued
# Saved: https://micenter.lt/lt/uzsienyje-igyti-diplomai
# Progress: 103 visited | 116 queued
# Saved: https://micenter.lt/lt/mokesciai
# Progress: 104 visited | 115 queued
# Saved: https://micenter.lt/lt/banko-saskaitos-atidarymas
# Progress: 105 visited | 115 queued
# Saved: https://micenter.lt/lt/paskolos
# Progress: 106 visited | 114 queued
# Saved: https://micenter.lt/lt/pajamu-deklaravimas
# Progress: 107 visited | 113 queued
# Saved: https://micenter.lt/lt/mokesciu-grazinimas
# Progress: 108 visited | 112 queued
# Saved: https://micenter.lt/lt/atvykimo-ismoka
# Progress: 109 visited | 111 queued
# Saved: https://micenter.lt/lt/ismokos-tevams
# Progress: 110 visited | 110 queued
# Saved: https://micenter.lt/lt/ismokos-vaikams
# Progress: 111 visited | 109 queued
# Saved: https://micenter.lt/lt/ligos-ir-nedarbo-ismokos
# Progress: 112 visited | 108 queued
# Saved: https://micenter.lt/lt/senatves-pensijos
# Progress: 113 visited | 107 queued
# Saved: https://micenter.lt/lt/humanitarine-pagalba
# Progress: 114 visited | 106 queued
# Saved: https://micenter.lt/lt/vaikai
# Progress: 115 visited | 105 queued
# Saved: https://micenter.lt/lt/santuoka
# Progress: 116 visited | 104 queued
# Saved: https://micenter.lt/lt/skyrybos
# Progress: 117 visited | 103 queued
# Saved: https://micenter.lt/lt/dviguba-pilietybe
# Progress: 118 visited | 102 queued
# Saved: https://micenter.lt/lt/lietuvos-pilietybe
# Progress: 119 visited | 101 queued
# Saved: https://micenter.lt/lt/vairuotojo-pazymejimas
# Progress: 120 visited | 100 queued
# Saved: https://micenter.lt/lt/vairavimo-egzaminai
# Progress: 121 visited | 99 queued
# Saved: https://micenter.lt/lt/transporto-priemones-registracija
# Progress: 122 visited | 98 queued
# Saved: https://micenter.lt/lt/automobilio-pirkimas
# Progress: 123 visited | 97 queued
# Saved: https://micenter.lt/lt/viesasis-transportas
# Progress: 124 visited | 96 queued
# Saved: https://micenter.lt/lt/el-paslaugos
# Progress: 125 visited | 95 queued
# Saved: https://micenter.lt/lt/apsipirkimas
# Progress: 126 visited | 94 queued
# Saved: https://micenter.lt/lt/telekomunikacija
# Progress: 127 visited | 93 queued
# Saved: https://micenter.lt/lt/komunaliniai-mokesciai
# Progress: 128 visited | 92 queued
# Saved: https://micenter.lt/lt/ka-daryti-nelaimes-atveju
# Progress: 129 visited | 91 queued
# Saved: https://micenter.lt/lt/rinkimai
# Progress: 130 visited | 90 queued
# Saved: https://micenter.lt/lt/kaip-tapti-vietiniu
# Progress: 131 visited | 89 queued
# Saved: https://micenter.lt/lt/gyvenimas-lietuvoje
# Progress: 132 visited | 100 queued
# Saved: https://micenter.lt/lt/karjeros-konsultacijos
# Progress: 133 visited | 99 queued
# Saved: https://micenter.lt/lt/psichologo-konsultacijos
# Progress: 134 visited | 98 queued
# Saved: https://micenter.lt/lt/kursai-apie-lietuva
# Progress: 135 visited | 97 queued
# Saved: https://micenter.lt/lt/teisine-pagalba
# Progress: 136 visited | 96 queued
# Saved: https://micenter.lt/lt/grupines-terapijos
# Progress: 137 visited | 95 queued
# Saved: https://micenter.lt/ru/izuchenie-litovskogo-yazyka
# Progress: 138 visited | 99 queued
# Saved: https://micenter.lt/ru/o-nas
# Progress: 139 visited | 98 queued
# Saved: https://micenter.lt/ru/osnovnaya-informatsiya
# Progress: 140 visited | 97 queued
# Saved: https://micenter.lt/ru/interesnye-fakty
# Progress: 141 visited | 96 queued
# Saved: https://micenter.lt/ru/statistika-po-migratsii
# Progress: 142 visited | 95 queued
# Saved: https://micenter.lt/ru/vezd-v-litvu
# Progress: 143 visited | 94 queued
# Saved: https://micenter.lt/ru/shengenskaya-viza
# Progress: 144 visited | 93 queued
# Saved: https://micenter.lt/ru/biza-d
# Progress: 145 visited | 92 queued
# Saved: https://micenter.lt/ru/vremennyi-vid-na-zhitelstvo
# Progress: 146 visited | 91 queued
# Saved: https://micenter.lt/ru/golubaya-karta-blue-card
# Progress: 147 visited | 90 queued
# Saved: https://micenter.lt/ru/postoyannyi-vid-na-zhitelstvo
# Progress: 148 visited | 89 queued
# Saved: https://micenter.lt/ru/vremennaya-zashchita
# Progress: 149 visited | 88 queued
# Saved: https://micenter.lt/ru/pribyvayushchim-iz-ukrainy
# Progress: 150 visited | 87 queued
# Saved: https://micenter.lt/ru/legalizatsiya-dokumentov
# Progress: 151 visited | 86 queued
# Saved: https://micenter.lt/ru/poisk-raboty
# Progress: 152 visited | 85 queued
# Saved: https://micenter.lt/ru/usloviya-truda
# Progress: 153 visited | 84 queued
# Saved: https://micenter.lt/ru/razreshenie-na-rabotu
# Progress: 154 visited | 83 queued
# Saved: https://micenter.lt/ru/smena-rabotodatelya
# Progress: 155 visited | 82 queued
# Saved: https://micenter.lt/ru/nachalo-biznesa
# Progress: 156 visited | 81 queued
# Saved: https://micenter.lt/ru/narusheniya-prav-rabotnikov
# Progress: 157 visited | 80 queued
# Saved: https://micenter.lt/ru/deklarirovanie-mesta-zhitelstva
# Progress: 158 visited | 79 queued
# Saved: https://micenter.lt/ru/arenda-zhilya
# Progress: 159 visited | 78 queued
# Saved: https://micenter.lt/ru/pokupka-nedvizhimosti
# Progress: 160 visited | 77 queued
# Saved: https://micenter.lt/ru/ipoteka
# Progress: 161 visited | 76 queued
# Saved: https://micenter.lt/ru/sistema-zdravookhraneniya
# Progress: 162 visited | 75 queued
# Saved: https://micenter.lt/ru/meditsinskoe-strakhovanie
# Progress: 163 visited | 74 queued
# Saved: https://micenter.lt/ru/vrachi
# Progress: 164 visited | 73 queued
# Saved: https://micenter.lt/ru/kliniki-i-bolnitsy
# Progress: 165 visited | 72 queued
# Saved: https://micenter.lt/ru/psikhologicheskaya-pomoshch
# Progress: 166 visited | 71 queued
# Saved: https://micenter.lt/ru/doshkolnoe-obrazovanie
# Progress: 167 visited | 70 queued
# Saved: https://micenter.lt/ru/shkoly
# Progress: 168 visited | 69 queued
# Saved: https://micenter.lt/ru/vysshee-obrazovanie
# Progress: 169 visited | 68 queued
# Saved: https://micenter.lt/ru/priznanie-obrazovaniya
# Progress: 170 visited | 67 queued
# Saved: https://micenter.lt/ru/nalogi
# Progress: 171 visited | 66 queued
# Saved: https://micenter.lt/ru/otkrytie-bankovskogo-scheta
# Progress: 172 visited | 65 queued
# Saved: https://micenter.lt/ru/kredity
# Progress: 173 visited | 64 queued
# Saved: https://micenter.lt/ru/deklaratsiya-dokhodov
# Progress: 174 visited | 63 queued
# Saved: https://micenter.lt/ru/vozvrat-nalogov
# Progress: 175 visited | 62 queued
# Saved: https://micenter.lt/ru/vyplata-po-pribytiyu
# Progress: 176 visited | 61 queued
# Saved: https://micenter.lt/ru/semeinye-posobiya
# Progress: 177 visited | 60 queued
# Saved: https://micenter.lt/ru/posobiya-na-detei
# Progress: 178 visited | 59 queued
# Saved: https://micenter.lt/ru/posobiya-po-bolezni-i-bezrabotitse
# Progress: 179 visited | 58 queued
# Saved: https://micenter.lt/ru/pensiya-po-starosti
# Progress: 180 visited | 57 queued
# Saved: https://micenter.lt/ru/gumanitarnaya-pomoshch
# Progress: 181 visited | 56 queued
# Saved: https://micenter.lt/ru/deti
# Progress: 182 visited | 55 queued
# Saved: https://micenter.lt/ru/registratsiya-braka
# Progress: 183 visited | 54 queued
# Saved: https://micenter.lt/ru/razvod
# Progress: 184 visited | 53 queued
# Saved: https://micenter.lt/ru/grazhdanstvo-litvy
# Progress: 185 visited | 52 queued
# Saved: https://micenter.lt/ru/dvoinoe-grazhdanstvo
# Progress: 186 visited | 51 queued
# Saved: https://micenter.lt/ru/voditelskie-prava
# Progress: 187 visited | 50 queued
# Saved: https://micenter.lt/ru/ekzameny-po-vozhdeniyu
# Progress: 188 visited | 49 queued
# Saved: https://micenter.lt/ru/registratsiya-avtomobilya
# Progress: 189 visited | 48 queued
# Saved: https://micenter.lt/ru/pokupka-avtomobilya
# Progress: 190 visited | 47 queued
# Saved: https://micenter.lt/ru/obshchestvennyi-transport
# Progress: 191 visited | 46 queued
# Saved: https://micenter.lt/ru/eluslugi
# Progress: 192 visited | 45 queued
# Saved: https://micenter.lt/ru/shoping
# Progress: 193 visited | 44 queued
# Saved: https://micenter.lt/ru/telekommunikatsii
# Progress: 194 visited | 43 queued
# Saved: https://micenter.lt/ru/scheta
# Progress: 195 visited | 42 queued
# Saved: https://micenter.lt/ru/chto-delat-v-sluchae-chrezvychainoi-situatsii
# Progress: 196 visited | 41 queued
# Saved: https://micenter.lt/ru/vybory
# Progress: 197 visited | 40 queued
# Saved: https://micenter.lt/ru/kak-stat-mestnym
# Progress: 198 visited | 39 queued
# Saved: https://micenter.lt/ru/zhizn-v-litve
# Progress: 199 visited | 50 queued
# Saved: https://micenter.lt/ru/rabota-v-litve
# Progress: 200 visited | 49 queued
# Saved: https://micenter.lt/ru/psikhologicheskoe-konsultirovanie
# Progress: 201 visited | 48 queued
# Saved: https://micenter.lt/ru/orientatsionnye-kursy
# Progress: 202 visited | 48 queued
# Saved: https://micenter.lt/ru/yuridicheskaya-pomoshch
# Progress: 203 visited | 47 queued
# Saved: https://micenter.lt/ru/gruppovye-terapii
# Progress: 204 visited | 46 queued
# Failed to retrieve https://micenter.lt/null (Status code: 404)
# Progress: 204 visited | 45 queued
# Saved: https://micenter.lt/en/why-learn-the-lithuanian-language
# Progress: 205 visited | 44 queued
# Saved: https://micenter.lt/en/legal-requirements
# Progress: 206 visited | 43 queued
# Saved: https://micenter.lt/en/exams-and-tests
# Progress: 207 visited | 42 queued
# Saved: https://micenter.lt/en/where-can-i-learn-lithuanian
# Progress: 208 visited | 45 queued
# Failed to retrieve https://micenter.lt/en/arriving-from-ukraine (Status code: 502)
# Progress: 208 visited | 44 queued
# Failed to retrieve https://micenter.lt/en/psychological-consultation (Status code: 404)
# Progress: 208 visited | 43 queued
# Failed to retrieve https://micenter.lt/en/Registration to the Group "Emotional aspects of migration" (Status code: 404)
# Progress: 208 visited | 42 queued
# Saved: https://micenter.lt/lt/kodel-verta-mokytis-lietuviu-kalbos
# Progress: 209 visited | 42 queued
# Saved: https://micenter.lt/lt/teises-aktu-reikalavimai
# Progress: 210 visited | 41 queued
# Saved: https://micenter.lt/lt/egzaminai-ir-testai
# Progress: 211 visited | 40 queued
# Saved: https://micenter.lt/lt/kur-mokytis-lietuviu-kalbos
# Progress: 212 visited | 42 queued
# Failed to retrieve https://micenter.lt/cdn-cgi/l/email-protection (Status code: 404)
# Progress: 212 visited | 41 queued
# Failed to retrieve https://micenter.lt/lt/www.migracija.lt  (Status code: 404)
# Progress: 212 visited | 40 queued
# Failed to retrieve https://micenter.lt/lt/www.migracija.lt (Status code: 404)
# Progress: 212 visited | 39 queued
# Failed to retrieve https://micenter.lt/lt/null (Status code: 404)
# Progress: 212 visited | 38 queued
# Failed to retrieve https://micenter.lt/lt/main-information (Status code: 404)
# Progress: 212 visited | 37 queued
# Failed to retrieve https://micenter.lt/lt/visa-d (Status code: 404)
# Progress: 212 visited | 36 queued
# Failed to retrieve https://micenter.lt/lt/job-search (Status code: 404)
# Progress: 212 visited | 35 queued
# Failed to retrieve https://micenter.lt/lt/declaration-of-residence (Status code: 404)
# Progress: 212 visited | 34 queued
# Failed to retrieve https://micenter.lt/lt/healthcare-system (Status code: 404)
# Progress: 212 visited | 33 queued
# Failed to retrieve https://micenter.lt/lt/pre-school-education (Status code: 404)
# Progress: 212 visited | 32 queued
# Failed to retrieve https://micenter.lt/lt/taxes (Status code: 404)
# Progress: 212 visited | 31 queued
# Failed to retrieve https://micenter.lt/lt/arrival-allowance (Status code: 404)
# Progress: 212 visited | 30 queued
# Failed to retrieve https://micenter.lt/lt/children (Status code: 404)
# Progress: 212 visited | 29 queued
# Failed to retrieve https://micenter.lt/lt/driving-licence (Status code: 404)
# Progress: 212 visited | 28 queued
# Failed to retrieve https://micenter.lt/lt/e-services (Status code: 404)
# Progress: 212 visited | 27 queued
# Failed to retrieve https://micenter.lt/lt/elections (Status code: 404)
# Progress: 212 visited | 26 queued
# Saved: https://micenter.lt/ru/pochemu-stoit-uchit-litovskii-yazyk
# Progress: 213 visited | 26 queued
# Saved: https://micenter.lt/ru/zakonodatelnye-trebovaniya
# Progress: 214 visited | 25 queued
# Saved: https://micenter.lt/ru/ekzameny-i-testy
# Progress: 215 visited | 24 queued
# Saved: https://micenter.lt/ru/gde-ya-mogu-vyuchit-litovskii-yazyk
# Progress: 216 visited | 27 queued
# Failed to retrieve https://micenter.lt/ru/null (Status code: 404)
# Progress: 216 visited | 26 queued
# Failed to retrieve https://micenter.lt/ru/main-information (Status code: 404)
# Progress: 216 visited | 25 queued
# Failed to retrieve https://micenter.lt/ru/visa-d (Status code: 404)
# Progress: 216 visited | 24 queued
# Failed to retrieve https://micenter.lt/ru/job-search (Status code: 404)
# Progress: 216 visited | 23 queued
# Failed to retrieve https://micenter.lt/ru/declaration-of-residence (Status code: 404)
# Progress: 216 visited | 22 queued
# Failed to retrieve https://micenter.lt/ru/healthcare-system (Status code: 404)
# Progress: 216 visited | 21 queued
# Failed to retrieve https://micenter.lt/ru/pre-school-education (Status code: 404)
# Progress: 216 visited | 20 queued
# Failed to retrieve https://micenter.lt/ru/taxes (Status code: 404)
# Progress: 216 visited | 19 queued
# Failed to retrieve https://micenter.lt/ru/arrival-allowance (Status code: 404)
# Progress: 216 visited | 18 queued
# Failed to retrieve https://micenter.lt/ru/children (Status code: 404)
# Progress: 216 visited | 17 queued
# Failed to retrieve https://micenter.lt/ru/driving-licence (Status code: 404)
# Progress: 216 visited | 16 queued
# Failed to retrieve https://micenter.lt/ru/e-services (Status code: 404)
# Progress: 216 visited | 15 queued
# Failed to retrieve https://micenter.lt/ru/elections (Status code: 404)
# Progress: 216 visited | 14 queued
# Failed to retrieve https://micenter.lt/ru/Предстоящие курсы запланированы на осень. Следите за нашими обновлениями здесь и на Facebook. (Status code: 404)
# Progress: 216 visited | 13 queued
# Saved: https://micenter.lt/en/vilnius
# Progress: 217 visited | 13 queued
# Saved: https://micenter.lt/en/kaunas
# Progress: 218 visited | 12 queued
# Saved: https://micenter.lt/en/klaipeda
# Progress: 219 visited | 11 queued
# Saved: https://micenter.lt/en/independent-learning
# Progress: 220 visited | 10 queued
# Saved: https://micenter.lt/lt/mokymasis-savarankiskai
# Progress: 221 visited | 9 queued
# Saved: https://micenter.lt/lt/vilnius
# Progress: 222 visited | 8 queued
# Saved: https://micenter.lt/lt/kaunas
# Progress: 223 visited | 7 queued
# Saved: https://micenter.lt/lt/klaipeda
# Progress: 224 visited | 6 queued
# Failed to retrieve https://micenter.lt/cdn-cgi/l/email-protection (Status code: 404)
# Progress: 224 visited | 5 queued
# Saved: https://micenter.lt/ru/vilnyus
# Progress: 225 visited | 6 queued
# Saved: https://micenter.lt/ru/kaunas
# Progress: 226 visited | 5 queued
# Saved: https://micenter.lt/ru/klaipeda
# Progress: 227 visited | 4 queued
# Saved: https://micenter.lt/ru/samostoyatelnoe-obuchenie
# Progress: 228 visited | 3 queued
# Failed to retrieve https://micenter.lt/en/null (Status code: 404)
# Progress: 228 visited | 2 queued
# Failed to retrieve https://micenter.lt/cdn-cgi/l/email-protection (Status code: 404)
# Progress: 228 visited | 1 queued
# Failed to retrieve https://micenter.lt/ru/null (Status code: 404)

# %% [markdown]
# ## ...
