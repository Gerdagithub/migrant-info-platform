# %% [markdown]
# ### Import libraries

# %%
# Core Python
import os
import json
import numpy as np
from ipynbname import path as nb_path
from pathlib import Path
from typing import TypedDict, List, Optional, Dict, Any
from dataclasses import dataclass, field
from typing import List
from pprint import pprint

# HTML Cleanup
from bs4 import BeautifulSoup, NavigableString
from bs4.element import Tag

# Json cleanup
from difflib import SequenceMatcher
import re

# %% [markdown]
# ### Constants

# %%
from constants import (
    CHATBOT_SERVICE_ROOT,
    RAW_DATA_DIR,
    CLEANED_DATA_DIR, 
    SITES_DIRS,
    URL_MAP_FILENAME,
    SITE_ELEMENTS_JSON_FILENAME,
    SITES_ELEMENTS_JSON_PATH,
    SAVED_TEXTS_PATH,
    MERGED_SITES_PATH,
    ALLOWED_TAGS,
    SIMILAR_TEXT_THRESHOLD
)

# %% [markdown]
# ### Cleaning HTMLs

# %% [markdown]
# #### HTML File Proccessing

# %%
# Helpers
def remove_links(text: str) -> str:
        # Removes [anything inside brackets]
        return re.sub(r"\[[^\[\]]*\]", "", text)

def normalize_for_comparison(text: str) -> str:
    text_no_links = remove_links(text)
    text_cleaned = text_no_links.lower().strip().replace('\xa0', ' ')
    return ' '.join(text_cleaned.split())

# %%
class HTMLCleaner:
    '''
    Cleans single HTML file
    '''
    def __init__(
        self,
        html_path: str,
        config: Optional[Dict[str, Any]] = None
    ):
        config = config or {}
        self.html_path: str = html_path
        self.allowed_tags = config.get("allowed_tags", [])
        self.debug: bool = config.get("debug", False)
        self.indent_for_saving_json = config.get("indent_for_saving_json", 4)
        self.SIMILAR_TEXT_THRESHOLD = config.get("SIMILAR_TEXT_THRESHOLD", 0.85)

    def load_html(self):
        with open(self.html_path, "r", encoding="utf-8") as f:
            self.soup = BeautifulSoup(f, "html.parser")
            
    def get_raw_html(self) -> BeautifulSoup:
        self.load_html()
        return self.soup

    def clean_html(self) -> BeautifulSoup:
        """
        Remove all tags except given in 'allowed_tags'
        Handle <a> only when inside a <p>: inline its text + href.
        Remove empty layout <div> but unwrap any <div> that has real text.
        """
        # ensure we have a parsed soup
        if not hasattr(self, "soup"):
            self.load_html()

        # First handle all <a> tags
        for a in list(self.soup.find_all("a")):
            # only keep if anchor is inside a paragraph
            if a.find_parent("p") or a.find_parent("li") or a.find_parent("ol") or a.find_parent("ul"):
                href = a.get("href", "").strip()
                text = a.get_text(strip=False)
                if text == "":
                    a.decompose()
                    continue
                
                # replace <a> with "text [href]"
                replacement = f"{text} [{href}]" if href else text
                a.replace_with(NavigableString(replacement))
            else:
                # drop menu or navigation links
                a.decompose()

        # Next process all other tags
        for tag in list(self.soup.find_all(True)):
            # guard against non‐Tags or tags with no name
            if not isinstance(tag, Tag) or tag.name is None:
                continue            
            
            name = tag.name.lower()
            if name in self.allowed_tags and not tag.get_text(strip=False) and not tag.find_all("br"):
                tag.decompose()
                continue
            if name in self.allowed_tags:
                continue

            if name == "div":
                # if there's no user‑visible text, drop it entirely
                if not tag.get_text(strip=False):
                    tag.decompose()
                else:
                    # unwrap to keep its children
                    tag.unwrap()
            else:
                # for any other disallowed tag, just unwrap it
                tag.unwrap()

        return self.soup

    def get_clean_soup(self) -> BeautifulSoup:
        """Load, clean, and return the BeautifulSoup tree in one call."""
        if not hasattr(self, "soup"):
            self.load_html()
        return self.clean_html()

    def convert_list_item_into_clean_text(self, li: Tag) -> str:
        # Convert <li> content into clean plain text
        return "• " + li.get_text(separator=" ", strip=False)

    def convert_br_into_clean_text(self, br: Tag) -> str:
        return "\n"

    def convert_p_into_clean_text(self, tag: Tag) -> str:
        return f"{tag.get_text(strip=False)}\n"
    
    def convert_header_into_clean_text(self, tag: Tag) -> str:
        name = tag.name.lower()
        text = tag.get_text(strip=False)
        
        header_level = int(name[1]) # Assuming that header number is single digit
        prefix = "#" * header_level
        return f"{prefix} {tag.get_text(strip=True)}\n"
        
    def convert_soup_to_clean_text(self, saved_texts: Optional[List[str]] = None) -> str:
        saved_texts = saved_texts if saved_texts is not None else []
        clean_soup = self.get_clean_soup()
        merged_text = ""
        
        tags = clean_soup.find_all(True)
        for tag in tags:
            name = tag.name.lower()

            # Potential text to be merged
            new_text = ""
            
            if name == "li":                
                new_text = self.convert_list_item_into_clean_text(tag) + "\n"

            elif name.startswith("h") and name[1:].isdigit():
                new_text = self.convert_header_into_clean_text(tag)

            elif name == 'p':
                new_text = self.convert_p_into_clean_text(tag)

            elif name == 'br':
                new_text = self.convert_br_into_clean_text(tag)

            if not new_text:
                continue

            is_new_el_different = True
            for saved_text in saved_texts:
                if abs(len(new_text) - len(saved_text)) > 500:
                    continue
                
                normalized_saved = normalize_for_comparison(saved_text)
                normalized_new = normalize_for_comparison(new_text)

                if abs(len(normalized_new) - len(normalized_saved)) > 20:
                    continue
                
                if SequenceMatcher(None, normalized_saved, normalized_new).ratio() > self.SIMILAR_TEXT_THRESHOLD:
                    is_new_el_different = False
                    break
            if is_new_el_different:
                merged_text += new_text
                saved_texts.append(new_text)
                with open(SAVED_TEXTS_PATH, "w", encoding="utf-8") as f:
                    json.dump(saved_texts, f, ensure_ascii=False, indent=4)
                            
        return merged_text

# %%
# from pprint import pprint

# config_html_cleaner = {
#     "allowed_tags": ALLOWED_TAGS,
#     "debug": True,
#     "indent_for_saving_json": 4
# }

# # Usage:
# html_filename = os.path.join(RAW_DATA_DIR, 'micenter_site', 'micenter.lt_en_change-of-employer.html')
# cleaner = HTMLCleaner(html_filename, config_html_cleaner)
# # clean_soup = cleaner.clean_html()
# # print(clean_soup.prettify())
# # print(cleaner.convert_soup_to_json())
# # pprint(cleaner.convert_soup_to_json(), width=120)
# base, _ = os.path.splitext(os.path.join(CLEANED_DATA_DIR, 'micenter_site', 'micenter.lt_en_change-of-employer.html'))
# saving_path = base + ".json"
# print(saving_path)
# # os.makedirs(os.path.join(CLEANED_DATA_DIR, 'micenter_site'), exist_ok=True) 
# text = cleaner.convert_soup_to_clean_text()
# pprint(text)

# %%
from pprint import pprint

config_html_cleaner = {
    "allowed_tags": ALLOWED_TAGS,
    "debug": True,
    "indent_for_saving_json": 4
}

# Usage:
html_filename = os.path.join(RAW_DATA_DIR, 'micenter_site', 'micenter.lt_en_change-of-employer.html')
cleaner = HTMLCleaner(html_filename, config_html_cleaner)
# clean_soup = cleaner.clean_html()
# print(clean_soup.prettify())
# print(cleaner.convert_soup_to_json())
# pprint(cleaner.convert_soup_to_json(), width=120)
base, _ = os.path.splitext(os.path.join(CLEANED_DATA_DIR, 'micenter_site', 'micenter.lt_en_change-of-employer.html'))
saving_path = base + ".json"
print(saving_path)
# os.makedirs(os.path.join(CLEANED_DATA_DIR, 'micenter_site'), exist_ok=True) 
text = cleaner.convert_soup_to_clean_text()
pprint(text)
# Out:
# /home/gerzem1/PDP/DCIP/migrant-info-platform/backend/chatbot_service/data/cleaned/micenter_site/micenter.lt_en_change-of-employer.json
# ('Toll-free hotline\n'
#  '0 800 22922 \n'
#  'Consultations will not \n'
#  'be available on 17 April \n'
#  '\n'
#  '\n'
#  'If you’re a foreigner working in Lithuania with a residence permit and want '
#  'to change employers, in most cased you’ll need to get permission '
#  '[https://www.migracija.lt/changing-employer] first. Your new employer will '
#  'need to send a mediation letter '
#  '[https://www.migracija.lt/app/form-wizard/mediation-letter] to the Migration '
#  'Department, and you’ll need to submit a request for approval. You can start '
#  'your new job only after receiving this permission.\n'
#  '## How to change employer in Lithuania?\n'
#  'For Non-Highly Skilled Occupations: If your residence permit isn’t for a '
#  'high-skilled job [/en/blue-card], you’ll need permission to change your '
#  'employer. You can apply for this change no sooner than 6 months after your '
#  'temporary residence permit was issued.\n'
#  'Decision Time: The Migration Department will make a decision within 1 '
#  'month.\n'
#  'Validity: The permit is valid for one month after the decision is made. \n'
#  'For EU Blue Card Holders in Lithuania - no Migration Department Decision '
#  'Required:\n'
#  '• If Employed for Over One Year: If you’ve been working legally in a '
#  'high-skilled job for over a year, just notify the Migration Department '
#  'through the MIGRIS system within 7 working days. No additional decision from '
#  'the Migration Department is needed.\n'
#  '• Changing Job Function: You don’t need permission to change your job '
#  'function with the same employer.\n'
#  'Requires Migration Department Decision:\n'
#  '• Within the First Year: If you want to switch employers within the first '
#  'year of legal employment, you’ll need a decision from the Migration '
#  'Department\n'
#  '• After Job Loss: If you end your job within 12 months of your Blue Card’s '
#  'issue date and want to start a new highly skilled job with another employer '
#  'within 6 months, you’ll need approval from the Migration Department.\n'
#  'Validity: The permit to change your employer or job position is valid for '
#  'one month after the decision is made.\n'
#  '## How to Apply for a Permit to Change Employer or Job Position?\n'
#  '• Your new or current employer (for job function changes) submits a  '
#  'mediation lette [https://www.migracija.lt/app/form-wizard/mediation-letter] '
#  'r through MIGRIS.\n'
#  '• Once you receive the mediation letter number, you can  submit your '
#  'application  [https://www.migracija.lt/changing-employer] in your personal '
#  'MIGRIS profile.\n'
#  'State Fee '
#  '[https://migracija.lrv.lt/lt/paslaugos/valstybes-rinkliavu-sarasas/leidimai-gyventi-2/]: '
#  '€100 for the application and decision.\n'
#  'IMPORTANT: You can only start with your new employer or change job functions '
#  'with the same employer after you’ve received approval from the Migration '
#  'Department.\n'
#  '\n'
#  'The International Organization for Migration (IOM) is part of the United '
#  'Nations System as the leading inter-governmental organization promoting '
#  'since 1951 humane and orderly migration for the benefit of all, with 175 '
#  'member states and a presence in over 100 countries. IOM has had a presence '
#  'in Lithuania since 1998.\n'
#  'IOM has established a Migration Information Center in Lithuania that '
#  'provides information and services to migrants to facilitate their '
#  'integration.\n'
#  '0 800 22922 (free line)\n'
#  '+370 525 14352\n'
#  'Jasinskio st. 16, II floor\n'
#  '\n'
#  ' '
#  '[https://www.google.com/maps/dir/54.7157558,25.266244/migration+information+center+lithuania/@54.7019533,25.2448175,14z/data=!3m1!4b1!4m9!4m8!1m1!4e1!1m5!1m1!1s0x46dd952291c16a0d:0x5ab716e3b0066f76!2m2!1d25.259492!2d54.6870158?entry=ttu&g_ep=EgoyMDI0MDkyNC4wIKXMDSoASAFQAw%3D%3D]\n')

# %% [markdown]
# #### Cleaning of All HTMLs

# %% [markdown]
# ## Merging All Data into a Single Json File

# %%
def make_text_source_entry(text: str = "", source: str = "") -> dict[str, str]:
    return {
        "text": text,
        "source": source
    }

class AllCleanedSitesData:
    """
    Cleaned data of all scraped sites in the same file.
    """
    def __init__(
        self, 
        sites_dirs: List[str],
        saved_texts: List[str],
        config: Dict[str, Any]
    ):
        if not isinstance(sites_dirs, list):
            raise TypeError("sites_dirs must be a list of strings.")
        self.sites_dirs: List[str] = sites_dirs

        REQUIRED_KEYS: Dict[str, type] = {
            "ALLOWED_TAGS": (list, set),
            "RAW_DATA_DIR": str,
            "CLEANED_DATA_DIR": str,
            "URL_MAP_FILENAME": str,
            "SITE_ELEMENTS_JSON_FILENAME": str,
            "SITES_ELEMENTS_JSON_PATH": str,
            "SIMILAR_TEXT_THRESHOLD": float
        }
        
        for key, expected_type in REQUIRED_KEYS.items():
            if key not in config:
                raise ValueError(f"Missing required config key: {key}")
            if not isinstance(config[key], expected_type):
                raise TypeError(
                    f"Config key '{key}' must be of type {expected_type.__name__}, "
                    f"got {type(config[key]).__name__}"
                )

        self.ALLOWED_TAGS = config["ALLOWED_TAGS"]
        self.RAW_DATA_DIR = config["RAW_DATA_DIR"]
        self.CLEANED_DATA_DIR = config["CLEANED_DATA_DIR"]
        self.URL_MAP_FILENAME = config["URL_MAP_FILENAME"]
        self.SITE_ELEMENTS_JSON_FILENAME = config["SITE_ELEMENTS_JSON_FILENAME"]
        self.SITES_ELEMENTS_JSON_PATH = config["SITES_ELEMENTS_JSON_PATH"]
        self.SIMILAR_TEXT_THRESHOLD = config["SIMILAR_TEXT_THRESHOLD"]

        self.html_cleaner_config = {
            "allowed_tags": self.ALLOWED_TAGS,
            "SIMILAR_TEXT_THRESHOLD": self.SIMILAR_TEXT_THRESHOLD,
            "debug": config.get("debug", False)
        }

        self.saved_texts = saved_texts # text chunks from every file

    def merge_cleaned_site_jsons(self, site_dir: str, use_existing_site_data: bool, save_site: bool) -> List[Dict[str, str]]:
        url_map_path = os.path.join(self.RAW_DATA_DIR, site_dir, self.URL_MAP_FILENAME)
        with open(url_map_path, 'r', encoding='utf-8') as file:
            url_map = json.load(file)

        data_path = os.path.join(self.CLEANED_DATA_DIR, site_dir, self.SITE_ELEMENTS_JSON_FILENAME)
        if use_existing_site_data and os.path.isfile(data_path):
            with open(data_path, "r") as f:
                site_elements_in_json = json.load(f)
        else:
            site_elements_in_json = []
            
        total_files = len(url_map)
        last_printed_percent = -10  # to ensure 0% prints immediately
        print(f"Processing: {site_dir}")
        
        for i, (html_filename, page_link) in enumerate(url_map.items(), start=1):
            print(f"[{site_dir}] Processing file {i}/{total_files}: {html_filename}")
            percent_complete = int((i / total_files) * 100)
            if percent_complete >= last_printed_percent + 10:
                print(f"Progress: {percent_complete}% ({i}/{total_files})")
                last_printed_percent = percent_complete

            path_with_base, extension = os.path.splitext(os.path.join(self.CLEANED_DATA_DIR, site_dir, html_filename))
            if extension != ".html":
                continue       
            
            html_path = os.path.join(self.RAW_DATA_DIR, site_dir, html_filename)
            if not os.path.isfile(html_path):
                print(f"Warning: File not found: {html_path}")
                continue
                
            if len(site_elements_in_json) > 0:
                resource_found = any(entry["source"] == page_link for entry in site_elements_in_json)
                if resource_found:
                    print(f"[{site_dir}] file {html_filename} was already processed. Going to the next one.")
                    continue
            
            html_cleaner = HTMLCleaner(html_path=html_path, config=self.html_cleaner_config)
            merged_clean_text = html_cleaner.convert_soup_to_clean_text(self.saved_texts)
            text_source_entry = make_text_source_entry(text=merged_clean_text, source=page_link)
            site_elements_in_json.append(text_source_entry)

            if not save_site:
                continue
            with open(data_path, "w", encoding="utf-8") as f:
                json.dump(site_elements_in_json, f, indent=4, ensure_ascii=False)
        
        return site_elements_in_json

    def site_elements_file_exists(self, site_dir: str) -> bool:
        filepath = os.path.join(self.CLEANED_DATA_DIR, site_dir, self.SITE_ELEMENTS_JSON_FILENAME)        
        return os.path.exists(filepath)
    
    def convert_sites_data_to_json_list(
        self, 
        merged_data: List[Dict[str, str]],
        merged_sites: List[str],
        append_to_existing: bool, 
        use_site_elements_file_if_exists: bool,
        save: bool = True
    ) -> List[Dict[str, str]]:   
        """
        Merges all sites data to single json list
        """
        merged_data = merged_data if append_to_existing else []

        for site_dir in self.sites_dirs:
            if site_dir in merged_sites:
                continue
            
            if use_site_elements_file_if_exists and self.site_elements_file_exists(site_dir):
                # use that file           
                site_data = self.merge_cleaned_site_jsons(site_dir=site_dir,
                                                          use_existing_site_data=True,
                                                          save_site=save)
            else:
                site_data = self.merge_cleaned_site_jsons(site_dir=site_dir,
                                                          use_existing_site_data=False,
                                                          save_site=save)
                
            merged_data.extend(site_data)
            merged_sites.append(site_dir)
            print(f"Processed: {site_dir}")

        return merged_data

# %%
config_all_sites_data = {
    "ALLOWED_TAGS": ALLOWED_TAGS,
    "RAW_DATA_DIR": RAW_DATA_DIR,
    "CLEANED_DATA_DIR": CLEANED_DATA_DIR,
    "URL_MAP_FILENAME": URL_MAP_FILENAME,
    "SITE_ELEMENTS_JSON_FILENAME": SITE_ELEMENTS_JSON_FILENAME,
    "SITES_ELEMENTS_JSON_PATH": SITES_ELEMENTS_JSON_PATH,
    "SIMILAR_TEXT_THRESHOLD": SIMILAR_TEXT_THRESHOLD
}

SAVED_TEXTS_PATH = os.path.join(CLEANED_DATA_DIR, 'saved_texts.json')
if os.path.exists(SAVED_TEXTS_PATH):
    with open(SAVED_TEXTS_PATH, 'r', encoding='utf-8') as file:
        saved_texts = json.load(file)
else:
    saved_texts = []

if os.path.exists(MERGED_SITES_PATH):
    with open(MERGED_SITES_PATH, 'r', encoding='utf-8') as file_m:
        merged_sites = json.load(file_m)
else:
    merged_sites = []

if os.path.exists(SITES_ELEMENTS_JSON_PATH):
    with open(SITES_ELEMENTS_JSON_PATH, 'r', encoding='utf-8') as file_s:
        sites_data = json.load(file_s)
else:
    sites_data = []
    
all_sites_data_handler = AllCleanedSitesData(sites_dirs=SITES_DIRS,
                                             saved_texts=saved_texts,
                                             config=config_all_sites_data)

sites_data = all_sites_data_handler.convert_sites_data_to_json_list(merged_data=sites_data,
                                                                    merged_sites=merged_sites, 
                                                                    append_to_existing=True,
                                                                    use_site_elements_file_if_exists=True,
                                                                    save=True)

with open(SAVED_TEXTS_PATH, "w", encoding="utf-8") as f: # TODO: go to every site_dir, get each text and append it to save_texts
    json.dump(saved_texts, f, ensure_ascii=False, indent=4)
with open(MERGED_SITES_PATH, "w", encoding="utf-8") as f:
    json.dump(merged_sites, f, ensure_ascii=False, indent=4)

print(f"✅ Elements from all cleaned sites merged and saved to {SITES_ELEMENTS_JSON_PATH}")
# Out:
# Processing: vmi_site
# [vmi_site] Processing file 1/1781: www.vmi.lt_evmi.html
# Progress: 0% (1/1781)
# [vmi_site] file www.vmi.lt_evmi.html was already processed. Going to the next one.
# [vmi_site] Processing file 2/1781: www.vmi.lt_evmi_svetaines-medis.html
# [vmi_site] file www.vmi.lt_evmi_svetaines-medis.html was already processed. Going to the next one.
# [vmi_site] Processing file 3/1781: www.vmi.lt_evmi_informacija-gestu-kalba.html
# [vmi_site] file www.vmi.lt_evmi_informacija-gestu-kalba.html was already processed. Going to the next one.
# [vmi_site] Processing file 4/1781: www.vmi.lt_evmi_lengvai-suprantama-kalba.html
# [vmi_site] file www.vmi.lt_evmi_lengvai-suprantama-kalba.html was already processed. Going to the next one.
# [vmi_site] Processing file 5/1781: sso.vmi.lt_sso_login.html
# [vmi_site] file sso.vmi.lt_sso_login.html was already processed. Going to the next one.
# [vmi_site] Processing file 6/1781: www.vmi.lt_evmi_mokesciu-moketoju-informacija.html
# [vmi_site] file www.vmi.lt_evmi_mokesciu-moketoju-informacija.html was already processed. Going to the next one.
# [vmi_site] Processing file 7/1781: www.vmi.lt_evmi_formos.html
# [vmi_site] file www.vmi.lt_evmi_formos.html was already processed. Going to the next one.
# [vmi_site] Processing file 8/1781: www.vmi.lt_evmi_rinkmenos.html
# [vmi_site] file www.vmi.lt_evmi_rinkmenos.html was already processed. Going to the next one.
# [vmi_site] Processing file 9/1781: www.vmi.lt_evmi_skaiciuokles.html
# [vmi_site] file www.vmi.lt_evmi_skaiciuokles.html was already processed. Going to the next one.
# [vmi_site] Processing file 10/1781: www.vmi.lt_evmi_saskaitos-ir-imoku-kodai.html
# [vmi_site] file www.vmi.lt_evmi_saskaitos-ir-imoku-kodai.html was already processed. Going to the next one.
# [vmi_site] Processing file 11/1781: www.vmi.lt_evmi_mokesciu-zinynas.html
# [vmi_site] file www.vmi.lt_evmi_mokesciu-zinynas.html was already processed. Going to the next one.
# [vmi_site] Processing file 12/1781: www.vmi.lt_evmi_mokes%C4%8Di%C5%B3-kalendorius.html
# [vmi_site] file www.vmi.lt_evmi_mokes%C4%8Di%C5%B3-kalendorius.html was already processed. Going to the next one.
# [vmi_site] Processing file 13/1781: www.vmi.lt_evmi_seminarai.html
# [vmi_site] file www.vmi.lt_evmi_seminarai.html was already processed. Going to the next one.
# [vmi_site] Processing file 14/1781: www.vmi.lt_evmi_tarptautiniai-isipareigojimai-fatca.html
# [vmi_site] file www.vmi.lt_evmi_tarptautiniai-isipareigojimai-fatca.html was already processed. Going to the next one.
# [vmi_site] Processing file 15/1781: www.vmi.lt_evmi_kontaktai.html
# [vmi_site] file www.vmi.lt_evmi_kontaktai.html was already processed. Going to the next one.
# [vmi_site] Processing file 16/1781: www.vmi.lt_evmi_deklaruoti-pajamas.html
# [vmi_site] file www.vmi.lt_evmi_deklaruoti-pajamas.html was already processed. Going to the next one.
# [vmi_site] Processing file 17/1781: www.vmi.lt_evmi_2025-metais.html
# [vmi_site] file www.vmi.lt_evmi_2025-metais.html was already processed. Going to the next one.
# [vmi_site] Processing file 18/1781: www.vmi.lt_evmi_ne-lietuvos-rezidentams.html
# [vmi_site] file www.vmi.lt_evmi_ne-lietuvos-rezidentams.html was already processed. Going to the next one.
# [vmi_site] Processing file 19/1781: www.vmi.lt_evmi_informacia-dla-gromadan-ukraini.html
# [vmi_site] file www.vmi.lt_evmi_informacia-dla-gromadan-ukraini.html was already processed. Going to the next one.
# [vmi_site] Processing file 20/1781: www.vmi.lt_evmi_domiuosi-nekilnojamojo-turto-mokesciu.html
# [vmi_site] file www.vmi.lt_evmi_domiuosi-nekilnojamojo-turto-mokesciu.html was already processed. Going to the next one.
# [vmi_site] Processing file 21/1781: www.vmi.lt_evmi_domiuosi-pridetines-vertes-mokesciu-pvm.html
# [vmi_site] file www.vmi.lt_evmi_domiuosi-pridetines-vertes-mokesciu-pvm.html was already processed. Going to the next one.
# [vmi_site] Processing file 22/1781: www.vmi.lt_evmi_pradedu-individualia-veikla.html
# [vmi_site] file www.vmi.lt_evmi_pradedu-individualia-veikla.html was already processed. Going to the next one.
# [vmi_site] Processing file 23/1781: www.vmi.lt_evmi_steigiu-imone.html
# [vmi_site] file www.vmi.lt_evmi_steigiu-imone.html was already processed. Going to the next one.
# [vmi_site] Processing file 24/1781: www.vmi.lt_evmi_gavau-pajamu-uzsienyje.html
# [vmi_site] file www.vmi.lt_evmi_gavau-pajamu-uzsienyje.html was already processed. Going to the next one.
# [vmi_site] Processing file 25/1781: www.vmi.lt_evmi_atstovauju-kita-asmeni-imone.html
# [vmi_site] file www.vmi.lt_evmi_atstovauju-kita-asmeni-imone.html was already processed. Going to the next one.
# [vmi_site] Processing file 26/1781: www.vmi.lt_evmi_gavau-turto-pardavimo_nuomos-pajam%C5%B3.html
# [vmi_site] file www.vmi.lt_evmi_gavau-turto-pardavimo_nuomos-pajam%C5%B3.html was already processed. Going to the next one.
# [vmi_site] Processing file 27/1781: www.vmi.lt_evmi_domiuosi-savo-permokomis-ir-skolomis.html
# [vmi_site] file www.vmi.lt_evmi_domiuosi-savo-permokomis-ir-skolomis.html was already processed. Going to the next one.
# [vmi_site] Processing file 28/1781: www.vmi.lt_evmi_atsiskaitymas-grynaisiais-pinigais.html
# [vmi_site] file www.vmi.lt_evmi_atsiskaitymas-grynaisiais-pinigais.html was already processed. Going to the next one.
# [vmi_site] Processing file 29/1781: www.vmi.lt_evmi_5552.html
# [vmi_site] file www.vmi.lt_evmi_5552.html was already processed. Going to the next one.
# [vmi_site] Processing file 30/1781: www.vmi.lt_evmi_i.eka.html
# [vmi_site] file www.vmi.lt_evmi_i.eka.html was already processed. Going to the next one.
# [vmi_site] Processing file 31/1781: www.vmi.lt_evmi_isankstine-rezervacija.html
# [vmi_site] file www.vmi.lt_evmi_isankstine-rezervacija.html was already processed. Going to the next one.
# [vmi_site] Processing file 32/1781: www.vmi.lt_evmi_gavau-itartina-pranesima-is-vmi.html
# [vmi_site] file www.vmi.lt_evmi_gavau-itartina-pranesima-is-vmi.html was already processed. Going to the next one.
# [vmi_site] Processing file 33/1781: www.vmi.lt_evmi_naujienos.html
# [vmi_site] file www.vmi.lt_evmi_naujienos.html was already processed. Going to the next one.
# [vmi_site] Processing file 34/1781: www.vmi.lt_evmi_-_nepamir-c5-a1kite-skirti-dal-c4-af-sumok-c4-97to-gpm-paramai_redirect-%2Fevmi%2F.html
# [vmi_site] file www.vmi.lt_evmi_-_nepamir-c5-a1kite-skirti-dal-c4-af-sumok-c4-97to-gpm-paramai_redirect-%2Fevmi%2F.html was already processed. Going to the next one.
# [vmi_site] Processing file 35/1781: www.vmi.lt_evmi_-_b-c5-abkite-budr-c5-abs-suk-c4-8diai-kuria-netikras-vmi-svetaines_redirect-%2Fevmi%2F.html
# [vmi_site] file www.vmi.lt_evmi_-_b-c5-abkite-budr-c5-abs-suk-c4-8diai-kuria-netikras-vmi-svetaines_redirect-%2Fevmi%2F.html was already processed. Going to the next one.
# [vmi_site] Processing file 36/1781: www.vmi.lt_evmi_mokesciu-naujienos.html
# [vmi_site] file www.vmi.lt_evmi_mokesciu-naujienos.html was already processed. Going to the next one.
# [vmi_site] Processing file 37/1781: www.vmi.lt_mvmi.html
# [vmi_site] file www.vmi.lt_mvmi.html was already processed. Going to the next one.
# [vmi_site] Processing file 38/1781: deklaravimas.vmi.lt_lt_Pradinis_Prisijungimo_puslapis_Prisijungimasperisorinessistemas.aspx.html
# [vmi_site] file deklaravimas.vmi.lt_lt_Pradinis_Prisijungimo_puslapis_Prisijungimasperisorinessistemas.aspx.html was already processed. Going to the next one.
# [vmi_site] Processing file 39/1781: imas.vmi.lt_index.html
# [vmi_site] file imas.vmi.lt_index.html was already processed. Going to the next one.
# [vmi_site] Processing file 40/1781: www.vmi.lt_epris_Login.aspx_ReturnUrl-%2Fepris%2F.html
# [vmi_site] file www.vmi.lt_epris_Login.aspx_ReturnUrl-%2Fepris%2F.html was already processed. Going to the next one.
# [vmi_site] Processing file 41/1781: www.vmi.lt_ties.html
# [vmi_site] file www.vmi.lt_ties.html was already processed. Going to the next one.
# [vmi_site] Processing file 42/1781: ais.vmi.lt_index.html
# [vmi_site] file ais.vmi.lt_index.html was already processed. Going to the next one.
# [vmi_site] Processing file 43/1781: sso.vmi.lt_sso_login&locale=lt.html
# [vmi_site] file sso.vmi.lt_sso_login&locale=lt.html was already processed. Going to the next one.
# [vmi_site] Processing file 44/1781: imas.vmi.lt_isaf_dynamicPage_aboutizur.html
# [vmi_site] file imas.vmi.lt_isaf_dynamicPage_aboutizur.html was already processed. Going to the next one.
# [vmi_site] Processing file 45/1781: www.vmi.lt_oss.html
# [vmi_site] file www.vmi.lt_oss.html was already processed. Going to the next one.
# [vmi_site] Processing file 46/1781: www.vmi.lt_svs.html
# [vmi_site] file www.vmi.lt_svs.html was already processed. Going to the next one.
# [vmi_site] Processing file 47/1781: www.vmi.lt_evmi_tax-consultations-at-international-house.html
# [vmi_site] file www.vmi.lt_evmi_tax-consultations-at-international-house.html was already processed. Going to the next one.
# [vmi_site] Processing file 48/1781: www.vmi.lt_evmi_documents_20142_1032511_Slapukupolitika2024-03-22.pdf_1e861a11-3912-5329-a31b-e37a5f276191_t-1711434699475.html
# [vmi_site] file www.vmi.lt_evmi_documents_20142_1032511_Slapukupolitika2024-03-22.pdf_1e861a11-3912-5329-a31b-e37a5f276191_t-1711434699475.html was already processed. Going to the next one.
# [vmi_site] Processing file 49/1781: www.vmi.lt_evmi_documents_20142_837401_DUOMENU+SAUGOS+POLITIKA.pdf_67bbeed0-e2b5-4af4-68f7-40c2cf3dfd75_t-1691499734422.html
# [vmi_site] file www.vmi.lt_evmi_documents_20142_837401_DUOMENU+SAUGOS+POLITIKA.pdf_67bbeed0-e2b5-4af4-68f7-40c2cf3dfd75_t-1691499734422.html was already processed. Going to the next one.
# [vmi_site] Processing file 50/1781: www.vmi.lt_evmi_misija-vizija-ir-vertyb%C4%97s.html
# [vmi_site] file www.vmi.lt_evmi_misija-vizija-ir-vertyb%C4%97s.html was already processed. Going to the next one.
# [vmi_site] Processing file 51/1781: www.vmi.lt_evmi_strukt%C5%ABra-ir-kontaktai.html
# [vmi_site] file www.vmi.lt_evmi_strukt%C5%ABra-ir-kontaktai.html was already processed. Going to the next one.
# [vmi_site] Processing file 52/1781: www.vmi.lt_evmi_konsultavimasis-su-visuomene.html
# [vmi_site] file www.vmi.lt_evmi_konsultavimasis-su-visuomene.html was already processed. Going to the next one.
# [vmi_site] Processing file 53/1781: www.vmi.lt_evmi_teisin%C4%97-informacija.html
# [vmi_site] file www.vmi.lt_evmi_teisin%C4%97-informacija.html was already processed. Going to the next one.
# [vmi_site] Processing file 54/1781: www.vmi.lt_evmi_peticiju-komisijos-veikla.html
# [vmi_site] file www.vmi.lt_evmi_peticiju-komisijos-veikla.html was already processed. Going to the next one.
# [vmi_site] Processing file 55/1781: www.vmi.lt_evmi_veiklos-sritys.html
# [vmi_site] file www.vmi.lt_evmi_veiklos-sritys.html was already processed. Going to the next one.
# [vmi_site] Processing file 56/1781: www.vmi.lt_evmi_kokyb%C4%97s-vadyba.html
# [vmi_site] file www.vmi.lt_evmi_kokyb%C4%97s-vadyba.html was already processed. Going to the next one.
# [vmi_site] Processing file 57/1781: www.vmi.lt_evmi_mokesciu-administravimo-proceduros.html
# [vmi_site] file www.vmi.lt_evmi_mokesciu-administravimo-proceduros.html was already processed. Going to the next one.
# [vmi_site] Processing file 58/1781: www.vmi.lt_evmi_korupcijos-prevencija.html
# [vmi_site] file www.vmi.lt_evmi_korupcijos-prevencija.html was already processed. Going to the next one.
# [vmi_site] Processing file 59/1781: www.vmi.lt_evmi_prane%C5%A1%C4%97j%C5%B3-apsauga.-vidinis-kanalas.html
# [vmi_site] file www.vmi.lt_evmi_prane%C5%A1%C4%97j%C5%B3-apsauga.-vidinis-kanalas.html was already processed. Going to the next one.
# [vmi_site] Processing file 60/1781: www.vmi.lt_evmi_administracin%C4%97-informacija.html
# [vmi_site] file www.vmi.lt_evmi_administracin%C4%97-informacija.html was already processed. Going to the next one.
# [vmi_site] Processing file 61/1781: www.vmi.lt_evmi_statistiniai-duomenys.html
# [vmi_site] file www.vmi.lt_evmi_statistiniai-duomenys.html was already processed. Going to the next one.
# [vmi_site] Processing file 62/1781: www.vmi.lt_evmi_asmens-duomenu-sauga.html
# [vmi_site] file www.vmi.lt_evmi_asmens-duomenu-sauga.html was already processed. Going to the next one.
# [vmi_site] Processing file 63/1781: www.vmi.lt_evmi_viesieji-pirkimai.html
# [vmi_site] file www.vmi.lt_evmi_viesieji-pirkimai.html was already processed. Going to the next one.
# [vmi_site] Processing file 64/1781: www.vmi.lt_evmi_karjera.html
# [vmi_site] file www.vmi.lt_evmi_karjera.html was already processed. Going to the next one.
# [vmi_site] Processing file 65/1781: www.vmi.lt_evmi_konsultacine-taryba.html
# [vmi_site] file www.vmi.lt_evmi_konsultacine-taryba.html was already processed. Going to the next one.
# [vmi_site] Processing file 66/1781: www.vmi.lt_evmi_polaris-2021-2025.html
# [vmi_site] file www.vmi.lt_evmi_polaris-2021-2025.html was already processed. Going to the next one.
# [vmi_site] Processing file 67/1781: www.vmi.lt_evmi_apklausos.html
# [vmi_site] file www.vmi.lt_evmi_apklausos.html was already processed. Going to the next one.
# [vmi_site] Processing file 68/1781: www.vmi.lt_evmi_vmi-teikiamos-paslaugos.html
# [vmi_site] file www.vmi.lt_evmi_vmi-teikiamos-paslaugos.html was already processed. Going to the next one.
# [vmi_site] Processing file 69/1781: www.vmi.lt_evmi_vmi-kliento-profilis.html
# [vmi_site] file www.vmi.lt_evmi_vmi-kliento-profilis.html was already processed. Going to the next one.
# [vmi_site] Processing file 70/1781: www.vmi.lt_evmi_mokesciai-ir-ju-dydziai1.html
# [vmi_site] file www.vmi.lt_evmi_mokesciai-ir-ju-dydziai1.html was already processed. Going to the next one.
# [vmi_site] Processing file 71/1781: www.vmi.lt_evmi_dazniausiai-uzduodami.html
# [vmi_site] file www.vmi.lt_evmi_dazniausiai-uzduodami.html was already processed. Going to the next one.
# [vmi_site] Processing file 72/1781: www.vmi.lt_evmi_mokesciu-abc1.html
# [vmi_site] file www.vmi.lt_evmi_mokesciu-abc1.html was already processed. Going to the next one.
# [vmi_site] Processing file 73/1781: www.vmi.lt_evmi_aukcionai-_e-parduotuve.html
# [vmi_site] file www.vmi.lt_evmi_aukcionai-_e-parduotuve.html was already processed. Going to the next one.
# [vmi_site] Processing file 74/1781: www.vmi.lt_evmi_informacija-apie-parduodama-valstybei-perduota-turta..html
# [vmi_site] file www.vmi.lt_evmi_informacija-apie-parduodama-valstybei-perduota-turta..html was already processed. Going to the next one.
# [vmi_site] Processing file 75/1781: www.vmi.lt_evmi_stop-seseliui.html
# [vmi_site] file www.vmi.lt_evmi_stop-seseliui.html was already processed. Going to the next one.
# [vmi_site] Processing file 76/1781: www.vmi.lt_evmi_nuorodos.html
# [vmi_site] file www.vmi.lt_evmi_nuorodos.html was already processed. Going to the next one.
# [vmi_site] Processing file 77/1781: www.vmi.lt_evmi_mic.html
# [vmi_site] file www.vmi.lt_evmi_mic.html was already processed. Going to the next one.
# [vmi_site] Processing file 78/1781: www.vmi.lt_mvmi_lt_ManoVMIep_CardsEp_Documents_Paklausimai_Edit_LP_Paklausimai.aspx.html
# [vmi_site] file www.vmi.lt_mvmi_lt_ManoVMIep_CardsEp_Documents_Paklausimai_Edit_LP_Paklausimai.aspx.html was already processed. Going to the next one.
# [vmi_site] Processing file 79/1781: www.vmi.lt_cdn-cgi_l_email-protection.html
# [vmi_site] file www.vmi.lt_cdn-cgi_l_email-protection.html was already processed. Going to the next one.
# [vmi_site] Processing file 80/1781: www.vmi.lt_evmi_pagrindinis.html
# [vmi_site] file www.vmi.lt_evmi_pagrindinis.html was already processed. Going to the next one.
# [vmi_site] Processing file 81/1781: www.vmi.lt_evmi_mokesciu-administratoriaus-nurodymas-atsiskaityti-negrynaisiais-pinigais.html
# [vmi_site] file www.vmi.lt_evmi_mokesciu-administratoriaus-nurodymas-atsiskaityti-negrynaisiais-pinigais.html was already processed. Going to the next one.
# [vmi_site] Processing file 82/1781: www.vmi.lt_evmi_asmenys-laiku-vykdantys-mokestinius-isipareigojimus-turintys-mokestine-nepriemoka.html
# [vmi_site] file www.vmi.lt_evmi_asmenys-laiku-vykdantys-mokestinius-isipareigojimus-turintys-mokestine-nepriemoka.html was already processed. Going to the next one.
# [vmi_site] Processing file 83/1781: www.vmi.lt_evmi_asmenys-nevykdantys-klaidingai-vykdantys-prievoles.html
# [vmi_site] file www.vmi.lt_evmi_asmenys-nevykdantys-klaidingai-vykdantys-prievoles.html was already processed. Going to the next one.
# [vmi_site] Processing file 84/1781: www.vmi.lt_evmi_banderoliu-tikrinimas.html
# [vmi_site] file www.vmi.lt_evmi_banderoliu-tikrinimas.html was already processed. Going to the next one.
# [vmi_site] Processing file 85/1781: www.vmi.lt_evmi_blankai.html
# [vmi_site] file www.vmi.lt_evmi_blankai.html was already processed. Going to the next one.
# [vmi_site] Processing file 86/1781: www.vmi.lt_evmi_daugiausiai-i-vmi-saskaita-sumokantys-mokesciu-moketojai.html
# [vmi_site] file www.vmi.lt_evmi_daugiausiai-i-vmi-saskaita-sumokantys-mokesciu-moketojai.html was already processed. Going to the next one.
# [vmi_site] Processing file 87/1781: www.vmi.lt_evmi_informacija-apie-akcizus.html
# [vmi_site] file www.vmi.lt_evmi_informacija-apie-akcizus.html was already processed. Going to the next one.
# [vmi_site] Processing file 88/1781: www.vmi.lt_evmi_vmi-administruojamu-akcizu-duomenys.html
# [vmi_site] file www.vmi.lt_evmi_vmi-administruojamu-akcizu-duomenys.html was already processed. Going to the next one.
# [vmi_site] Processing file 89/1781: www.vmi.lt_evmi_juridinio-asmens-sumoketa-mokesciu-suma.html
# [vmi_site] file www.vmi.lt_evmi_juridinio-asmens-sumoketa-mokesciu-suma.html was already processed. Going to the next one.
# [vmi_site] Processing file 90/1781: www.vmi.lt_evmi_kasos-aparatai1.html
# [vmi_site] file www.vmi.lt_evmi_kasos-aparatai1.html was already processed. Going to the next one.
# [vmi_site] Processing file 91/1781: www.vmi.lt_evmi_laiduotoju-ir-garantu-registravimo-zurnalas.html
# [vmi_site] file www.vmi.lt_evmi_laiduotoju-ir-garantu-registravimo-zurnalas.html was already processed. Going to the next one.
# [vmi_site] Processing file 92/1781: www.vmi.lt_evmi_metines-gyventojo-seimos-turto-deklaracijos-duomenu-israsai.html
# [vmi_site] file www.vmi.lt_evmi_metines-gyventojo-seimos-turto-deklaracijos-duomenu-israsai.html was already processed. Going to the next one.
# [vmi_site] Processing file 93/1781: www.vmi.lt_evmi_atviri-duomenys.html
# [vmi_site] file www.vmi.lt_evmi_atviri-duomenys.html was already processed. Going to the next one.
# [vmi_site] Processing file 94/1781: www.vmi.lt_evmi_paramos-gaveju-ir-politiniu-organizaciju-duomenys.html
# [vmi_site] file www.vmi.lt_evmi_paramos-gaveju-ir-politiniu-organizaciju-duomenys.html was already processed. Going to the next one.
# [vmi_site] Processing file 95/1781: www.vmi.lt_evmi_pvm-lengvatu-sandeliai.html
# [vmi_site] file www.vmi.lt_evmi_pvm-lengvatu-sandeliai.html was already processed. Going to the next one.
# [vmi_site] Processing file 96/1781: www.vmi.lt_evmi_pvm-grazinimas-uzsienio-keleiviams.html
# [vmi_site] file www.vmi.lt_evmi_pvm-grazinimas-uzsienio-keleiviams.html was already processed. Going to the next one.
# [vmi_site] Processing file 97/1781: www.vmi.lt_evmi_raginimai-atvykti-pas-mokesciu-administrator.html
# [vmi_site] file www.vmi.lt_evmi_raginimai-atvykti-pas-mokesciu-administrator.html was already processed. Going to the next one.
# [vmi_site] Processing file 98/1781: www.vmi.lt_evmi_zemes-mokesciu-apmokestinamu-sklypu-duomenys.html
# [vmi_site] file www.vmi.lt_evmi_zemes-mokesciu-apmokestinamu-sklypu-duomenys.html was already processed. Going to the next one.
# [vmi_site] Processing file 99/1781: www.vmi.lt_evmi_prasymu-formos.html
# [vmi_site] file www.vmi.lt_evmi_prasymu-formos.html was already processed. Going to the next one.
# [vmi_site] Processing file 100/1781: www.vmi.lt_evmi_pvm-skaiciuokle-skirta-pvm-moketojais-neiregistruotiems-asmenims.html
# [vmi_site] file www.vmi.lt_evmi_pvm-skaiciuokle-skirta-pvm-moketojais-neiregistruotiems-asmenims.html was already processed. Going to the next one.
# [vmi_site] Processing file 101/1781: www.vmi.lt_evmi_imoku-kodai.html
# [vmi_site] file www.vmi.lt_evmi_imoku-kodai.html was already processed. Going to the next one.
.html
# [vmi_site] file www.vmi.lt_evmi_pranesimas-apie-gautus-priimtus-atsiskaitymus-ir-_-ar-bet-kokius-kitus-mokejimus-pagal-sandori-grynaisiais-pinigais-prc915-.html was already processed. Going to the next one.
# [vmi_site] Processing file 119/1781: www.vmi.lt_evmi_taksi-dispeceriniu-teikiami-duomenys.html
# [vmi_site] file www.vmi.lt_evmi_taksi-dispeceriniu-teikiami-duomenys.html was already processed. Going to the next one.
# [vmi_site] Processing file 120/1781: www.vmi.lt_evmi_pranesimas-apie-paskolas-atskaitingu-asmenu-isiskolinimus-dalyviu-imokas-ismokas-uzsienio-vienetams-fr0711-.html
# [vmi_site] file www.vmi.lt_evmi_pranesimas-apie-paskolas-atskaitingu-asmenu-isiskolinimus-dalyviu-imokas-ismokas-uzsienio-vienetams-fr0711-.html was already processed. Going to the next one.
# [vmi_site] Processing file 121/1781: www.vmi.lt_evmi_28.html
# [vmi_site] file www.vmi.lt_evmi_28.html was already processed. Going to the next one.
# [vmi_site] Processing file 122/1781: www.vmi.lt_evmi_duomenys-apie-asmens-saskaitu-likucius-metines-saskaitu-iplaukas-ir-skolinius-isipareigojimus.html
# [vmi_site] file www.vmi.lt_evmi_duomenys-apie-asmens-saskaitu-likucius-metines-saskaitu-iplaukas-ir-skolinius-isipareigojimus.html was already processed. Going to the next one.
# [vmi_site] Processing file 123/1781: www.vmi.lt_evmi_duomenys-apie-atidarytas-uzdarytas-saskaitas-seifo-kameru-nuoma-asmenu-atstovus-ir-naudos-gavejus.html
# [vmi_site] file www.vmi.lt_evmi_duomenys-apie-atidarytas-uzdarytas-saskaitas-seifo-kameru-nuoma-asmenu-atstovus-ir-naudos-gavejus.html was already processed. Going to the next one.
# [vmi_site] Processing file 124/1781: www.vmi.lt_evmi_tarptautiniai-duomenu-teikimo-isipareigojimai.html
# [vmi_site] file www.vmi.lt_evmi_tarptautiniai-duomenu-teikimo-isipareigojimai.html was already processed. Going to the next one.
# [vmi_site] Processing file 125/1781: www.vmi.lt_evmi_uzsienio-saskaitoms-taikomu-mokestiniu-prievoliu-vykdymo-akto-igyvendinimo-susitarimas-angl.-fatca-.html
# [vmi_site] file www.vmi.lt_evmi_uzsienio-saskaitoms-taikomu-mokestiniu-prievoliu-vykdymo-akto-igyvendinimo-susitarimas-angl.-fatca-.html was already processed. Going to the next one.
# [vmi_site] Processing file 126/1781: www.vmi.lt_evmi_bendrasis-duomenu-teikimo-standartas-angl.-crs-.html
# [vmi_site] file www.vmi.lt_evmi_bendrasis-duomenu-teikimo-standartas-angl.-crs-.html was already processed. Going to the next one.
# [vmi_site] Processing file 127/1781: www.vmi.lt_evmi_tarptautiniu-imoniu-grupiu-teikiamos-ataskaitos.html
# [vmi_site] file www.vmi.lt_evmi_tarptautiniu-imoniu-grupiu-teikiamos-ataskaitos.html was already processed. Going to the next one.
# [vmi_site] Processing file 128/1781: www.vmi.lt_evmi_pranestini-tarpvalstybiniai-susitarimai-dac6.html
# [vmi_site] file www.vmi.lt_evmi_pranestini-tarpvalstybiniai-susitarimai-dac6.html was already processed. Going to the next one.
# [vmi_site] Processing file 129/1781: www.vmi.lt_evmi_platformu-operatoriu-duomenu-teikimas-dac7-.html
# [vmi_site] file www.vmi.lt_evmi_platformu-operatoriu-duomenu-teikimas-dac7-.html was already processed. Going to the next one.
# [vmi_site] Processing file 130/1781: www.vmi.lt_evmi_duomenu-apie-tarptautines-mokejimo-operacijas-teikimas-cesop-.html
# [vmi_site] file www.vmi.lt_evmi_duomenu-apie-tarptautines-mokejimo-operacijas-teikimas-cesop-.html was already processed. Going to the next one.
# [vmi_site] Processing file 131/1781: www.vmi.lt_evmi_pranesimas-apie-nenuolatinius-lietuvos-gyventojus-dirbancius-pagal-laikinojo-idarbinimo-sutartis-fr1147-.html
# [vmi_site] file www.vmi.lt_evmi_pranesimas-apie-nenuolatinius-lietuvos-gyventojus-dirbancius-pagal-laikinojo-idarbinimo-sutartis-fr1147-.html was already processed. Going to the next one.
# [vmi_site] Processing file 132/1781: www.vmi.lt_evmi_pranesimas-apie-finansines-saskaitas-fr0526-rrc910-.html
# [vmi_site] file www.vmi.lt_evmi_pranesimas-apie-finansines-saskaitas-fr0526-rrc910-.html was already processed. Going to the next one.
# [vmi_site] Processing file 133/1781: www.vmi.lt_evmi_pranesimas-apie-sudarytus-sandorius-prc907-.html
# [vmi_site] file www.vmi.lt_evmi_pranesimas-apie-sudarytus-sandorius-prc907-.html was already processed. Going to the next one.
# [vmi_site] Processing file 134/1781: www.vmi.lt_evmi_informacijos-teikimas-apie-atsiskaityma-uz-zemes-ukio-produkcija-fr1070-.html
# [vmi_site] file www.vmi.lt_evmi_informacijos-teikimas-apie-atsiskaityma-uz-zemes-ukio-produkcija-fr1070-.html was already processed. Going to the next one.
# [vmi_site] Processing file 135/1781: www.vmi.lt_evmi_pranesimas-apie-turto-isigijimo-saltinius-prc911-.html
# [vmi_site] file www.vmi.lt_evmi_pranesimas-apie-turto-isigijimo-saltinius-prc911-.html was already processed. Going to the next one.
# [vmi_site] Processing file 136/1781: www.vmi.lt_evmi_palukanu-gautu-is-taupymo-pajamu-ismokejimas-gpm306-.html
# [vmi_site] file www.vmi.lt_evmi_palukanu-gautu-is-taupymo-pajamu-ismokejimas-gpm306-.html was already processed. Going to the next one.
# [vmi_site] Processing file 137/1781: www.vmi.lt_evmi_prasymai-pazymos-ir-mokejimo-duomenys.html
# [vmi_site] file www.vmi.lt_evmi_prasymai-pazymos-ir-mokejimo-duomenys.html was already processed. Going to the next one.
# [vmi_site] Processing file 138/1781: www.vmi.lt_evmi_%C4%AEmok%C5%B3-kodai-ir-mok%C4%97jimo-informacija.html
# [vmi_site] file www.vmi.lt_evmi_%C4%AEmok%C5%B3-kodai-ir-mok%C4%97jimo-informacija.html was already processed. Going to the next one.
# [vmi_site] Processing file 139/1781: www.vmi.lt_evmi_registracija-mm-registre-pvm-registre.html
# [vmi_site] file www.vmi.lt_evmi_registracija-mm-registre-pvm-registre.html was already processed. Going to the next one.
# [vmi_site] Processing file 140/1781: www.vmi.lt_evmi_juridinio-asmens-pranesimas-apie-jo-duomenu-pakeitima-fr0791-.html
# [vmi_site] file www.vmi.lt_evmi_juridinio-asmens-pranesimas-apie-jo-duomenu-pakeitima-fr0791-.html was already processed. Going to the next one.
# [vmi_site] Processing file 141/1781: www.vmi.lt_evmi_fizinio-asmens-prasymas-iregistruoti-i-mmr-reg812-.html
# [vmi_site] file www.vmi.lt_evmi_fizinio-asmens-prasymas-iregistruoti-i-mmr-reg812-.html was already processed. Going to the next one.
# [vmi_site] Processing file 142/1781: www.vmi.lt_evmi_uzsienio-juridinio-asmens-prasymas-iregistruoti-i_isregistruoti-is-mmr-fr0227-.html
# [vmi_site] file www.vmi.lt_evmi_uzsienio-juridinio-asmens-prasymas-iregistruoti-i_isregistruoti-is-mmr-fr0227-.html was already processed. Going to the next one.
# [vmi_site] Processing file 143/1781: www.vmi.lt_evmi_diplomatiniu-atstovybiu-konsuliniu-istaigu-ir-tarptautiniu-organizaciju-prasymas-reg806-.html
# [vmi_site] file www.vmi.lt_evmi_diplomatiniu-atstovybiu-konsuliniu-istaigu-ir-tarptautiniu-organizaciju-prasymas-reg806-.html was already processed. Going to the next one.
# [vmi_site] Processing file 144/1781: www.vmi.lt_evmi_prasymas-iregistruoti-i_isregistruoti-is-pvm-moketoju-registro-fr0388-.html
# [vmi_site] file www.vmi.lt_evmi_prasymas-iregistruoti-i_isregistruoti-is-pvm-moketoju-registro-fr0388-.html was already processed. Going to the next one.
# [vmi_site] Processing file 145/1781: www.vmi.lt_evmi_ekonomines-veiklos-rusiu-klasifikatorius-evrk-.html
# [vmi_site] file www.vmi.lt_evmi_ekonomines-veiklos-rusiu-klasifikatorius-evrk-.html was already processed. Going to the next one.
# [vmi_site] Processing file 146/1781: www.vmi.lt_evmi_pazymu-uzsakymas-ir-prasymu-teikimas.html
# [vmi_site] file www.vmi.lt_evmi_pazymu-uzsakymas-ir-prasymu-teikimas.html was already processed. Going to the next one.
# [vmi_site] Processing file 147/1781: www.vmi.lt_evmi_prasymas-del-mokescio-permokos-grazinimo-iskaitymo-fr0781-.html
# [vmi_site] file www.vmi.lt_evmi_prasymas-del-mokescio-permokos-grazinimo-iskaitymo-fr0781-.html was already processed. Going to the next one.
# [vmi_site] Processing file 148/1781: www.vmi.lt_evmi_prasymas-del-akcizu-grazinimo-fr0396-fr0397-.html
# [vmi_site] file www.vmi.lt_evmi_prasymas-del-akcizu-grazinimo-fr0396-fr0397-.html was already processed. Going to the next one.
# [vmi_site] Processing file 149/1781: www.vmi.lt_evmi_prasymas-isdestyti-atideti-mokesciu-ar-baudu-sumokejima.html
# [vmi_site] file www.vmi.lt_evmi_prasymas-isdestyti-atideti-mokesciu-ar-baudu-sumokejima.html was already processed. Going to the next one.
# [vmi_site] Processing file 150/1781: www.vmi.lt_evmi_prasymas-del-mokestines-nepriemokos-peremimo.html
# [vmi_site] file www.vmi.lt_evmi_prasymas-del-mokestines-nepriemokos-peremimo.html was already processed. Going to the next one.
# [vmi_site] Processing file 151/1781: www.vmi.lt_evmi_prasymas-del-atsiskaitymo-su-valstybes-biudzetu-fr0319-.html
# [vmi_site] file www.vmi.lt_evmi_prasymas-del-atsiskaitymo-su-valstybes-biudzetu-fr0319-.html was already processed. Going to the next one.
# [vmi_site] Processing file 152/1781: www.vmi.lt_evmi_prasymas-del-pazymos-apie-gautas-pajamas-ir-sumoketus-mokescius-fr0594-fr0595-.html
# [vmi_site] file www.vmi.lt_evmi_prasymas
6290: www.sodra.lt_lt_situacijos_informacija-gyventojams_noriu-gauti-salpos-ismoka.html
# [sodra_site] Processing file 118/6290: www.sodra.lt_lt_situacijos_informacija-gyventojams_ka-daryti-jei-patyriau-trauma.html
# [sodra_site] Processing file 119/6290: www.sodra.lt_lt_situacijos_informacija-gyventojams_noriu-gauti-nedarbingumo-pazymejima-del-epidemines-situacijos.html
# [sodra_site] Processing file 120/6290: www.sodra.lt_lt_situacijos_informacija-gyventojams_ka-daryti-jei-netekau-artimuju.html
# [sodra_site] Processing file 121/6290: www.sodra.lt_lt_situacijos_informacija-gyventojams_kitos-pensijos-ir-ismokos.html
# [sodra_site] Processing file 122/6290: www.sodra.lt_lt_situacijos_informacija-gyventojams_draudimas-valstybes-lesomis-1.html
# [sodra_site] Processing file 123/6290: www.sodra.lt_lt_situacijos_informacija-draudejams_imoku-tarifai.html
# [sodra_site] Processing file 124/6290: www.sodra.lt_lt_situacijos_informacija-draudejams_imoku-kodai.html
# [sodra_site] Processing file 125/6290: www.sodra.lt_lt_situacijos_informacija-draudejams_noriu-sumoketi-imokas_ar-galiu-skola-sodrai-sumoketi-dalimis.html
# [sodra_site] Processing file 126/6290: www.sodra.lt_lt_situacijos_informacija-draudejams_noriu-sumoketi-imokas_savarankiskai-moku-psd-imokas.html
# [sodra_site] Processing file 127/6290: www.sodra.lt_lt_situacijos_informacija-draudejams_noriu-sumoketi-imokas_vykdau-individualia-veikla.html
# [sodra_site] Processing file 128/6290: www.sodra.lt_lt_situacijos_informacija-draudejams_noriu-sumoketi-imokas_turiu-verslo-liudijima-1.html
# [sodra_site] Processing file 129/6290: www.sodra.lt_lt_situacijos_informacija-draudejams_noriu-sumoketi-imokas_esu-individualios-imones-savininkas.html
# [sodra_site] Processing file 130/6290: www.sodra.lt_lt_situacijos_informacija-draudejams_noriu-sumoketi-imokas_turiu-samdomu-darbuotoju.html
# [sodra_site] Processing file 131/6290: www.sodra.lt_lt_situacijos_informacija-draudejams_noriu-sumoketi-imokas_dirbu-pagal-autorine-sutartinoriu-idarbinti-pagal-autorine-sutarti.html
# [sodra_site] Processing file 132/6290: www.sodra.lt_lt_situacijos_informacija-draudejams_noriu-sumoketi-imokas_verciuosi-individualia-zemes-ukio-veikla.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 34
#      28     sites_data = []
#      30 all_sites_data_handler = AllCleanedSitesData(sites_dirs=SITES_DIRS,
#      31                                              saved_texts=saved_texts,
#      32                                              config=config_all_sites_data)
# ---> 34 sites_data = all_sites_data_handler.convert_sites_data_to_json_list(merged_data=sites_data,
#      35                                                                     merged_sites=merged_sites,
#      36                                                                     append_to_existing=True,
#      37                                                                     use_site_elements_file_if_exists=True,
#      38                                                                     save=True)
#      40 with open(SAVED_TEXTS_PATH, "w", encoding="utf-8") as f: # TODO: go to every site_dir, get each text and append it to save_texts
#      41     json.dump(saved_texts, f, ensure_ascii=False, indent=4)
#
# Cell In[15], line 133, in AllCleanedSitesData.convert_sites_data_to_json_list(self, merged_data, merged_sites, append_to_existing, use_site_elements_file_if_exists, save)
#     129     site_data = self.merge_cleaned_site_jsons(site_dir=site_dir,
#     130                                               use_existing_site_data=True,
#     131                                               save_site=save)
#     132 else:
# --> 133     site_data = self.merge_cleaned_site_jsons(site_dir=site_dir,
#     134                                               use_existing_site_data=False,
#     135                                               save_site=save)
#     137 merged_data.extend(site_data)
#     138 merged_sites.append(site_dir)
#
# Cell In[15], line 95, in AllCleanedSitesData.merge_cleaned_site_jsons(self, site_dir, use_existing_site_data, save_site)
#      92         continue
#      94 html_cleaner = HTMLCleaner(html_path=html_path, config=self.html_cleaner_config)
# ---> 95 merged_clean_text = html_cleaner.convert_soup_to_clean_text(self.saved_texts)
#      96 text_source_entry = make_text_source_entry(text=merged_clean_text, source=page_link)
#      97 site_elements_in_json.append(text_source_entry)
#
# Cell In[12], line 140, in HTMLCleaner.convert_soup_to_clean_text(self, saved_texts)
#     137 if abs(len(normalized_new) - len(normalized_saved)) > 20:
#     138     continue
# --> 140 if SequenceMatcher(None, normalized_saved, normalized_new).ratio() > self.SIMILAR_TEXT_THRESHOLD:
#     141     is_new_el_different = False
#     142     break
#
# File /opt/conda/lib/python3.12/difflib.py:619, in SequenceMatcher.ratio(self)
#     597 def ratio(self):
#     598     """Return a measure of the sequences' similarity (float in [0,1]).
#     599
#     600     Where T is the total number of elements in both sequences, and
#    (...)
#     616     1.0
#     617     """
# --> 619     matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     620     return _calculate_ratio(matches, len(self.a) + len(self.b))
#
# File /opt/conda/lib/python3.12/difflib.py:454, in SequenceMatcher.get_matching_blocks(self)
#     452 while queue:
#     453     alo, ahi, blo, bhi = queue.pop()
# --> 454     i, j, k = x = self.find_longest_match(alo, ahi, blo, bhi)
#     455     # a[alo:i] vs b[blo:j] unknown
#     456     # a[i:i+k] same as b[j:j+k]
#     457     # a[i+k:ahi] vs b[j+k:bhi] unknown
#     458     if k:   # if k is 0, there was no matching block
#
# File /opt/conda/lib/python3.12/difflib.py:379, in SequenceMatcher.find_longest_match(self, alo, ahi, blo, bhi)
#     377 j2lenget = j2len.get
#     378 newj2len = {}
# --> 379 for j in b2j.get(a[i], nothing):
#     380     # a[i] matches b[j]
#     381     if j < blo:
#     382         continue
#
# KeyboardInterrupt:

# %%
config_all_sites_data = {
    "ALLOWED_TAGS": ALLOWED_TAGS,
    "RAW_DATA_DIR": RAW_DATA_DIR,
    "CLEANED_DATA_DIR": CLEANED_DATA_DIR,
    "URL_MAP_FILENAME": URL_MAP_FILENAME,
    "SITE_ELEMENTS_JSON_FILENAME": SITE_ELEMENTS_JSON_FILENAME,
    "SITES_ELEMENTS_JSON_PATH": SITES_ELEMENTS_JSON_PATH,
    "SIMILAR_TEXT_THRESHOLD": SIMILAR_TEXT_THRESHOLD
}

all_sites_data_handler = AllCleanedSitesData(sites_dirs=SITES_DIRS, config=config_all_sites_data)
sites_data = all_sites_data_handler.convert_sites_data_to_json_list()
print(f"✅ Elements from {SITES_DIRS} sites merged and saved to {SITES_ELEMENTS_JSON_PATH}")
# Out:
# Processing: micenter_site
# Progressing micenter.lt_en.html (1)
# Progress: 0% (1/228)
# Progressing micenter.lt_lt.html (2)
# Progressing micenter.lt_ru.html (3)
# Progressing micenter.lt_en_learn-lithuanian.html (4)
# Progressing micenter.lt_en_about-us.html (5)
# Progressing micenter.lt_index.html (6)
# Progressing micenter.lt_en_main-information.html (7)
# Progressing micenter.lt_en_interesting-facts.html (8)
# Progressing micenter.lt_en_migration-statistics.html (9)
# Progressing micenter.lt_en_travel-to-lithuania.html (10)
# Progressing micenter.lt_en_schengen-visa.html (11)
# Progressing micenter.lt_en_visa-d.html (12)
# Progressing micenter.lt_en_temporary-residence-permit.html (13)
# Progressing micenter.lt_en_blue-card.html (14)
# Progressing micenter.lt_en_permanent-residence-permit.html (15)
# Progressing micenter.lt_en_temporary-protection.html (16)
# Progressing micenter.lt_en_legalization-of-documents.html (17)
# Progressing micenter.lt_en_job-search.html (18)
# Progressing micenter.lt_en_working-conditions.html (19)
# Progressing micenter.lt_en_work-permit.html (20)
# Progressing micenter.lt_en_change-of-employer.html (21)
# Progressing micenter.lt_en_starting-a-business.html (22)
# Progressing micenter.lt_en_violations-of-workers-rights.html (23)
# Progress: 10% (23/228)
# Progressing micenter.lt_en_declaration-of-residence.html (24)
# Progressing micenter.lt_en_rental-accomodation.html (25)
# Progressing micenter.lt_en_property-purchase.html (26)
# Progressing micenter.lt_en_mortgage.html (27)
# Progressing micenter.lt_en_healthcare-system.html (28)
# Progressing micenter.lt_en_health-insurance.html (29)
# Progressing micenter.lt_en_doctors.html (30)
# Progressing micenter.lt_en_clinics-and-hospitals.html (31)
# Progressing micenter.lt_en_psychological-assistance.html (32)
# Progressing micenter.lt_en_pre-school-education.html (33)
# Progressing micenter.lt_en_schools.html (34)
# Progressing micenter.lt_en_study-in-lithuania.html (35)
# Progressing micenter.lt_en_recognition-of-foreign-qualifications.html (36)
# Progressing micenter.lt_en_taxes.html (37)
# Progressing micenter.lt_en_opening-bank-account.html (38)
# Progressing micenter.lt_en_loans.html (39)
# Progressing micenter.lt_en_income-declaration.html (40)
# Progressing micenter.lt_en_tax-refund.html (41)
# Progressing micenter.lt_en_arrival-allowance.html (42)
# Progressing micenter.lt_en_benefits-for-parents.html (43)
# Progressing micenter.lt_en_shild-benefits.html (44)
# Progressing micenter.lt_en_social-benefits.html (45)
# Progressing micenter.lt_en_old-age-pension.html (46)
# Progress: 20% (46/228)
# Progressing micenter.lt_en_humanitarian-aid.html (47)
# Progressing micenter.lt_en_children.html (48)
# Progressing micenter.lt_en_getting-married.html (49)
# Progressing micenter.lt_en_divorce.html (50)
# Progressing micenter.lt_en_dual-citizenship.html (51)
# Progressing micenter.lt_en_lithuanian-citizenship.html (52)
# Progressing micenter.lt_en_driving-licence.html (53)
# Progressing micenter.lt_en_driving-exams.html (54)
# Progressing micenter.lt_en_vehicle-registration.html (55)
# Progressing micenter.lt_en_buying-a-vehicle.html (56)
# Progressing micenter.lt_en_public-transport.html (57)
# Progressing micenter.lt_en_e-services.html (58)
# Progressing micenter.lt_en_shopping.html (59)
# Progressing micenter.lt_en_telecommunications.html (60)
# Progressing micenter.lt_en_bills.html (61)
# Progressing micenter.lt_en_what-to-do-in-a-case-of-emergency.html (62)
# Progressing micenter.lt_en_elections.html (63)
# Progressing micenter.lt_en_how-to-become-a-local.html (64)
# Progressing micenter.lt_en_living-in-lithuania.html (65)
# Progressing micenter.lt_en_work-in-lithuania.html (66)
# Progressing micenter.lt_en_psychological-counselling.html (67)
# Progressing micenter.lt_en_orientation-courses.html (68)
# Progressing micenter.lt_en_legal-advice.html (69)
# Progress: 30% (69/228)
# Progressing micenter.lt_en_group-therapies.html (70)
# Progressing micenter.lt_lt_lietuviu-kalbos-mokymasis.html (71)
# Progressing micenter.lt_lt_apie-mus.html (72)
# Progressing micenter.lt_lt_pagrindine-informacija.html (73)
# Progressing micenter.lt_lt_idomus-faktai.html (74)
# Progressing micenter.lt_lt_migracijos-statistika.html (75)
# Progressing micenter.lt_lt_atvykimas-i-lietuva.html (76)
# Progressing micenter.lt_lt_sengeno-viza.html (77)
# Progressing micenter.lt_lt_viza-d.html (78)
# Progressing micenter.lt_lt_leidimas-laikinai-gyventi.html (79)
# Progressing micenter.lt_lt_melynoji-kortele.html (80)
# Progressing micenter.lt_lt_leidimas-nuolat-gyventi.html (81)
# Progressing micenter.lt_lt_laikinoji-apsauga.html (82)
# Progressing micenter.lt_lt_atvykstantiems-is-ukrainos.html (83)
# Progressing micenter.lt_lt_dokumentu-legalizavimas.html (84)
# Progressing micenter.lt_lt_darbo-paieska.html (85)
# Progressing micenter.lt_lt_darbo-salygos.html (86)
# Progressing micenter.lt_lt_leidimas-dirbti.html (87)
# Progressing micenter.lt_lt_darbdavio-keitimas.html (88)
# Progressing micenter.lt_lt_verslo-pradzia.html (89)
# Progressing micenter.lt_lt_darbuotoju-teisiu-pazeidimai.html (90)
# Progressing micenter.lt_lt_gyvenamosios-vietos-deklaravimas.html (91)
# Progressing micenter.lt_lt_busto-nuoma.html (92)
# Progress: 40% (92/228)
# Progressing micenter.lt_lt_busto-pirkimas.html (93)
# Progressing micenter.lt_lt_busto-paskola.html (94)
# Progressing micenter.lt_lt_sveikatos-prieziuros-sistema.html (95)
# Progressing micenter.lt_lt_sveikatos-draudimas.html (96)
# Progressing micenter.lt_lt_gydytojai.html (97)
# Progressing micenter.lt_lt_ligonines-ir-klinikos.html (98)
# Progressing micenter.lt_lt_psichologine-pagalba.html (99)
# Progressing micenter.lt_lt_darzeliai-ir-priesmokyklinis-ugdymas.html (100)
# Progressing micenter.lt_lt_mokyklos.html (101)
# Progressing micenter.lt_lt_studijos.html (102)
# Progressing micenter.lt_lt_uzsienyje-igyti-diplomai.html (103)
# Progressing micenter.lt_lt_mokesciai.html (104)
# Progressing micenter.lt_lt_banko-saskaitos-atidarymas.html (105)
# Progressing micenter.lt_lt_paskolos.html (106)
# Progressing micenter.lt_lt_pajamu-deklaravimas.html (107)
# Progressing micenter.lt_lt_mokesciu-grazinimas.html (108)
# Progressing micenter.lt_lt_atvykimo-ismoka.html (109)
# Progressing micenter.lt_lt_ismokos-tevams.html (110)
# Progressing micenter.lt_lt_ismokos-vaikams.html (111)
# Progressing micenter.lt_lt_ligos-ir-nedarbo-ismokos.html (112)
# Progressing micenter.lt_lt_senatves-pensijos.html (113)
# Progressing micenter.lt_lt_humanitarine-pagalba.html (114)
# Progress: 50% (114/228)
# Progressing micenter.lt_lt_vaikai.html (115)
# Progressing micenter.lt_lt_santuoka.html (116)
# Progressing micenter.lt_lt_skyrybos.html (117)
# Progressing micenter.lt_lt_dviguba-pilietybe.html (118)
# Progressing micenter.lt_lt_lietuvos-pilietybe.html (119)
# Progressing micenter.lt_lt_vairuotojo-pazymejimas.html (120)
# Progressing micenter.lt_lt_vairavimo-egzaminai.html (121)
# Progressing micenter.lt_lt_transporto-priemones-registracija.html (122)
# Progressing micenter.lt_lt_automobilio-pirkimas.html (123)
# Progressing micenter.lt_lt_viesasis-transportas.html (124)
# Progressing micenter.lt_lt_el-paslaugos.html (125)
# Progressing micenter.lt_lt_apsipirkimas.html (126)
# Progressing micenter.lt_lt_telekomunikacija.html (127)
# Progressing micenter.lt_lt_komunaliniai-mokesciai.html (128)
# Progressing micenter.lt_lt_ka-daryti-nelaimes-atveju.html (129)
# Progressing micenter.lt_lt_rinkimai.html (130)
# Progressing micenter.lt_lt_kaip-tapti-vietiniu.html (131)
# Progressing micenter.lt_lt_gyvenimas-lietuvoje.html (132)
# Progressing micenter.lt_lt_karjeros-konsultacijos.html (133)
# Progressing micenter.lt_lt_psichologo-konsultacijos.html (134)
# Progressing micenter.lt_lt_kursai-apie-lietuva.html (135)
# Progressing micenter.lt_lt_teisine-pagalba.html (136)
# Progressing micenter.lt_lt_grupines-terapijos.html (137)
# Progress: 60% (137/228)
# Progressing micenter.lt_ru_izuchenie-litovskogo-yazyka.html (138)
# Progressing micenter.lt_ru_o-nas.html (139)
# Progressing micenter.lt_ru_osnovnaya-informatsiya.html (140)
# Progressing micenter.lt_ru_interesnye-fakty.html (141)
# Progressing micenter.lt_ru_statistika-po-migratsii.html (142)
# Progressing micenter.lt_ru_vezd-v-litvu.html (143)
# Progressing micenter.lt_ru_shengenskaya-viza.html (144)
# Progressing micenter.lt_ru_biza-d.html (145)
# Progressing micenter.lt_ru_vremennyi-vid-na-zhitelstvo.html (146)
# Progressing micenter.lt_ru_golubaya-karta-blue-card.html (147)
# Progressing micenter.lt_ru_postoyannyi-vid-na-zhitelstvo.html (148)
# Progressing micenter.lt_ru_vremennaya-zashchita.html (149)
# Progressing micenter.lt_ru_pribyvayushchim-iz-ukrainy.html (150)
# Progressing micenter.lt_ru_legalizatsiya-dokumentov.html (151)
# Progressing micenter.lt_ru_poisk-raboty.html (152)
# Progressing micenter.lt_ru_usloviya-truda.html (153)
# Progressing micenter.lt_ru_razreshenie-na-rabotu.html (154)
# Progressing micenter.lt_ru_smena-rabotodatelya.html (155)
# Progressing micenter.lt_ru_nachalo-biznesa.html (156)
# Progressing micenter.lt_ru_narusheniya-prav-rabotnikov.html (157)
# Progressing micenter.lt_ru_deklarirovanie-mesta-zhitelstva.html (158)
# Progressing micenter.lt_ru_arenda-zhilya.html (159)
# Progressing micenter.lt_ru_pokupka-nedvizhimosti.html (160)
# Progress: 70% (160/228)
# Progressing micenter.lt_ru_ipoteka.html (161)
# Progressing micenter.lt_ru_sistema-zdravookhraneniya.html (162)
# Progressing micenter.lt_ru_meditsinskoe-strakhovanie.html (163)
# Progressing micenter.lt_ru_vrachi.html (164)
# Progressing micenter.lt_ru_kliniki-i-bolnitsy.html (165)
# Progressing micenter.lt_ru_psikhologicheskaya-pomoshch.html (166)
# Progressing micenter.lt_ru_doshkolnoe-obrazovanie.html (167)
# Progressing micenter.lt_ru_shkoly.html (168)
# Progressing micenter.lt_ru_vysshee-obrazovanie.html (169)
# Progressing micenter.lt_ru_priznanie-obrazovaniya.html (170)
# Progressing micenter.lt_ru_nalogi.html (171)
# Progressing micenter.lt_ru_otkrytie-bankovskogo-scheta.html (172)
# Progressing micenter.lt_ru_kredity.html (173)
# Progressing micenter.lt_ru_deklaratsiya-dokhodov.html (174)
# Progressing micenter.lt_ru_vozvrat-nalogov.html (175)
# Progressing micenter.lt_ru_vyplata-po-pribytiyu.html (176)
# Progressing micenter.lt_ru_semeinye-posobiya.html (177)
# Progressing micenter.lt_ru_posobiya-na-detei.html (178)
# Progressing micenter.lt_ru_posobiya-po-bolezni-i-bezrabotitse.html (179)
# Progressing micenter.lt_ru_pensiya-po-starosti.html (180)
# Progressing micenter.lt_ru_gumanitarnaya-pomoshch.html (181)
# Progressing micenter.lt_ru_deti.html (182)
# Progressing micenter.lt_ru_registratsiya-braka.html (183)
# Progress: 80% (183/228)
# Progressing micenter.lt_ru_razvod.html (184)
# Progressing micenter.lt_ru_grazhdanstvo-litvy.html (185)
# Progressing micenter.lt_ru_dvoinoe-grazhdanstvo.html (186)
# Progressing micenter.lt_ru_voditelskie-prava.html (187)
# Progressing micenter.lt_ru_ekzameny-po-vozhdeniyu.html (188)
# Progressing micenter.lt_ru_registratsiya-avtomobilya.html (189)
# Progressing micenter.lt_ru_pokupka-avtomobilya.html (190)
# Progressing micenter.lt_ru_obshchestvennyi-transport.html (191)
# Progressing micenter.lt_ru_eluslugi.html (192)
# Progressing micenter.lt_ru_shoping.html (193)
# Progressing micenter.lt_ru_telekommunikatsii.html (194)
# Progressing micenter.lt_ru_scheta.html (195)
# Progressing micenter.lt_ru_chto-delat-v-sluchae-chrezvychainoi-situatsii.html (196)
# Progressing micenter.lt_ru_vybory.html (197)
# Progressing micenter.lt_ru_kak-stat-mestnym.html (198)
# Progressing micenter.lt_ru_zhizn-v-litve.html (199)
# Progressing micenter.lt_ru_rabota-v-litve.html (200)
# Progressing micenter.lt_ru_psikhologicheskoe-konsultirovanie.html (201)
# Progressing micenter.lt_ru_orientatsionnye-kursy.html (202)
# Progressing micenter.lt_ru_yuridicheskaya-pomoshch.html (203)
# Progressing micenter.lt_ru_gruppovye-terapii.html (204)
# Progressing micenter.lt_en_why-learn-the-lithuanian-language.html (205)
# Progressing micenter.lt_en_legal-requirements.html (206)
# Progress: 90% (206/228)
# Progressing micenter.lt_en_exams-and-tests.html (207)
# Progressing micenter.lt_en_where-can-i-learn-lithuanian.html (208)
# Progressing micenter.lt_lt_kodel-verta-mokytis-lietuviu-kalbos.html (209)
# Progressing micenter.lt_lt_teises-aktu-reikalavimai.html (210)
# Progressing micenter.lt_lt_egzaminai-ir-testai.html (211)
# Progressing micenter.lt_lt_kur-mokytis-lietuviu-kalbos.html (212)
# Progressing micenter.lt_ru_pochemu-stoit-uchit-litovskii-yazyk.html (213)
# Progressing micenter.lt_ru_zakonodatelnye-trebovaniya.html (214)
# Progressing micenter.lt_ru_ekzameny-i-testy.html (215)
# Progressing micenter.lt_ru_gde-ya-mogu-vyuchit-litovskii-yazyk.html (216)
# Progressing micenter.lt_en_vilnius.html (217)
# Progressing micenter.lt_en_kaunas.html (218)
# Progressing micenter.lt_en_klaipeda.html (219)
# Progressing micenter.lt_en_independent-learning.html (220)
# Progressing micenter.lt_lt_mokymasis-savarankiskai.html (221)
# Progressing micenter.lt_lt_vilnius.html (222)
# Progressing micenter.lt_lt_kaunas.html (223)
# Progressing micenter.lt_lt_klaipeda.html (224)
# Progressing micenter.lt_ru_vilnyus.html (225)
# Progressing micenter.lt_ru_kaunas.html (226)
# Progressing micenter.lt_ru_klaipeda.html (227)
# Progressing micenter.lt_ru_samostoyatelnoe-obuchenie.html (228)
# Progress: 100% (228/228)
# Processed: micenter_site
# ✅ Elements from all cleaned sites merged and saved to /home/gerzem1/PDP/DCIP/migrant-info-platform/backend/chatbot_service/data/cleaned/sites_elements.json
